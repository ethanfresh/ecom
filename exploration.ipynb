# %%
import pandas as pd
df = pd.read_csv('25314841/conjura_mmm_data.csv')
# Out:
# /Users/ethanfreshman/anaconda3/lib/python3.11/site-packages/pandas/core/computation/expressions.py:22: UserWarning: Pandas requires version '2.10.2' or newer of 'numexpr' (version '2.8.7' currently installed).
#   from pandas.core.computation.check import NUMEXPR_INSTALLED
# /Users/ethanfreshman/anaconda3/lib/python3.11/site-packages/pandas/core/arrays/masked.py:56: UserWarning: Pandas requires version '1.4.2' or newer of 'bottleneck' (version '1.3.5' currently installed).
#   from pandas.core import (

# %%
df
# Out:
#                        MMM_TIMESERIES_ID                   ORGANISATION_ID  \
# 0       596eef7c71f933d820d0e485935d0e8f  04769dac8b828ec7a85676d9e2bffe6f
# 1       596eef7c71f933d820d0e485935d0e8f  04769dac8b828ec7a85676d9e2bffe6f
# 2       596eef7c71f933d820d0e485935d0e8f  04769dac8b828ec7a85676d9e2bffe6f
# 3       596eef7c71f933d820d0e485935d0e8f  04769dac8b828ec7a85676d9e2bffe6f
# 4       596eef7c71f933d820d0e485935d0e8f  04769dac8b828ec7a85676d9e2bffe6f
# ...                                  ...                               ...
# 132754  21ae5756595080e735f52426db421505  ff5c2c32d7f1c21594c518fc6a6d4fce
# 132755  21ae5756595080e735f52426db421505  ff5c2c32d7f1c21594c518fc6a6d4fce
# 132756  21ae5756595080e735f52426db421505  ff5c2c32d7f1c21594c518fc6a6d4fce
# 132757  21ae5756595080e735f52426db421505  ff5c2c32d7f1c21594c518fc6a6d4fce
# 132758  21ae5756595080e735f52426db421505  ff5c2c32d7f1c21594c518fc6a6d4fce
#
#        ORGANISATION_VERTICAL ORGANISATION_SUBVERTICAL  \
# 0           Beauty & Fitness                Hair Care
# 1           Beauty & Fitness                Hair Care
# 2           Beauty & Fitness                Hair Care
# 3           Beauty & Fitness                Hair Care
# 4           Beauty & Fitness                Hair Care
# ...                      ...                      ...
# 132754               Apparel                    Other
# 132755               Apparel                    Other
# 132756               Apparel                    Other
# 132757               Apparel                    Other
# 132758               Apparel                    Other
#
#        ORGANISATION_MARKETING_SOURCES ORGANISATION_PRIMARY_TERRITORY_NAME  \
# 0                        Google, Meta                                  US
# 1                        Google, Meta                                  US
# 2                        Google, Meta                                  US
# 3                        Google, Meta                                  US
# 4                        Google, Meta                                  US
# ...                               ...                                 ...
# 132754                   Google, Meta                                  US
# 132755                   Google, Meta                                  US
# 132756                   Google, Meta                                  US
# 132757                   Google, Meta                                  US
# 132758                   Google, Meta                                  US
#
#          TERRITORY_NAME    DATE_DAY CURRENCY_CODE  FIRST_PURCHASES  ...  \
# 0       All Territories  2022-07-29           USD               22  ...
# 1       All Territories  2022-07-30           USD               14  ...
# 2       All Territories  2022-07-31           USD               31  ...
# 3       All Territories  2022-08-01           USD               18  ...
# 4       All Territories  2022-08-02           USD               23  ...
# ...                 ...         ...           ...              ...  ...
# 132754  All Territories  2024-05-15           USD               14  ...
# 132755  All Territories  2024-05-16           USD               12  ...
# 132756  All Territories  2024-05-17           USD                7  ...
# 132757  All Territories  2024-05-18           USD               14  ...
# 132758  All Territories  2024-05-19           USD               10  ...
#
#         META_FACEBOOK_IMPRESSIONS  META_INSTAGRAM_IMPRESSIONS  \
# 0                         18997.0                         NaN
# 1                         20188.0                         NaN
# 2                         24718.0                         NaN
# 3                         25076.0                         NaN
# 4                         22688.0                         NaN
# ...                           ...                         ...
# 132754                    50550.0                         NaN
# 132755                    51024.0                         NaN
# 132756                    41637.0                         NaN
# 132757                    37661.0                         NaN
# 132758                    34170.0                         NaN
#
#         META_OTHER_IMPRESSIONS  TIKTOK_IMPRESSIONS  DIRECT_CLICKS  \
# 0                          NaN                 NaN          139.0
# 1                          NaN                 NaN          209.0
# 2                          NaN                 NaN          262.0
# 3                          NaN                 NaN          247.0
# 4                          NaN                 NaN          255.0
# ...                        ...                 ...            ...
# 132754                     NaN                 NaN          294.0
# 132755                     NaN                 NaN          206.0
# 132756                     NaN                 NaN          216.0
# 132757                     NaN                 NaN          951.0
# 132758                     NaN                 NaN          401.0
#
#         BRANDED_SEARCH_CLICKS  ORGANIC_SEARCH_CLICKS  EMAIL_CLICKS  \
# 0                         NaN                  300.0           1.0
# 1                         NaN                  442.0           8.0
# 2                         NaN                  427.0         631.0
# 3                         NaN                  400.0         117.0
# 4                         NaN                  425.0          37.0
# ...                       ...                    ...           ...
# 132754                  204.0                  234.0        1624.0
# 132755                  212.0                  209.0         225.0
# 132756                  186.0                  213.0          88.0
# 132757                  169.0                  190.0         167.0
# 132758                   83.0                  178.0          56.0
#
#         REFERRAL_CLICKS  ALL_OTHER_CLICKS
# 0                  61.0              40.0
# 1                 110.0              62.0
# 2                 108.0              65.0
# 3                 125.0              68.0
# 4                 146.0              65.0
# ...                 ...               ...
# 132754             54.0             380.0
# 132755             48.0             335.0
# 132756             40.0             706.0
# 132757             37.0             366.0
# 132758             41.0             933.0
#
# [132759 rows x 50 columns]

# %%
nan_counts = (df.isna().mean() * 100).sort_values(ascending=False)
nan_counts
# Out:
# TIKTOK_SPEND                           97.392267
# TIKTOK_IMPRESSIONS                     97.392267
# TIKTOK_CLICKS                          97.392267
# GOOGLE_VIDEO_CLICKS                    94.254250
# GOOGLE_VIDEO_SPEND                     94.254250
# GOOGLE_VIDEO_IMPRESSIONS               94.254250
# GOOGLE_DISPLAY_CLICKS                  85.879677
# GOOGLE_DISPLAY_IMPRESSIONS             85.879677
# GOOGLE_DISPLAY_SPEND                   85.879677
# META_OTHER_CLICKS                      82.264856
# META_OTHER_SPEND                       82.264856
# META_OTHER_IMPRESSIONS                 82.264856
# META_INSTAGRAM_SPEND                   79.800240
# META_INSTAGRAM_CLICKS                  79.800240
# META_INSTAGRAM_IMPRESSIONS             79.800240
# GOOGLE_PMAX_SPEND                      53.957171
# GOOGLE_PMAX_IMPRESSIONS                53.957171
# GOOGLE_PMAX_CLICKS                     53.957171
# GOOGLE_SHOPPING_IMPRESSIONS            40.508741
# GOOGLE_SHOPPING_SPEND                  40.508741
# GOOGLE_SHOPPING_CLICKS                 40.508741
# META_FACEBOOK_CLICKS                   39.656069
# META_FACEBOOK_IMPRESSIONS              39.656069
# META_FACEBOOK_SPEND                    39.656069
# BRANDED_SEARCH_CLICKS                  33.093048
# GOOGLE_PAID_SEARCH_CLICKS              27.208701
# GOOGLE_PAID_SEARCH_SPEND               27.208701
# GOOGLE_PAID_SEARCH_IMPRESSIONS         27.208701
# DIRECT_CLICKS                          25.774524
# EMAIL_CLICKS                           10.617736
# REFERRAL_CLICKS                         8.302262
# ALL_OTHER_CLICKS                        8.271379
# ORGANIC_SEARCH_CLICKS                   7.575381
# ORGANISATION_VERTICAL                   6.108814
# ORGANISATION_SUBVERTICAL                6.108814
# ORGANISATION_ID                         0.000000
# ALL_PURCHASES_GROSS_DISCOUNT            0.000000
# ORGANISATION_MARKETING_SOURCES          0.000000
# ORGANISATION_PRIMARY_TERRITORY_NAME     0.000000
# TERRITORY_NAME                          0.000000
# DATE_DAY                                0.000000
# CURRENCY_CODE                           0.000000
# FIRST_PURCHASES                         0.000000
# FIRST_PURCHASES_UNITS                   0.000000
# FIRST_PURCHASES_ORIGINAL_PRICE          0.000000
# FIRST_PURCHASES_GROSS_DISCOUNT          0.000000
# ALL_PURCHASES                           0.000000
# ALL_PURCHASES_UNITS                     0.000000
# ALL_PURCHASES_ORIGINAL_PRICE            0.000000
# MMM_TIMESERIES_ID                       0.000000
# dtype: float64

# %%
df.columns
# Out:
# Index(['MMM_TIMESERIES_ID', 'ORGANISATION_ID', 'ORGANISATION_VERTICAL',
#        'ORGANISATION_SUBVERTICAL', 'ORGANISATION_MARKETING_SOURCES',
#        'ORGANISATION_PRIMARY_TERRITORY_NAME', 'TERRITORY_NAME', 'DATE_DAY',
#        'CURRENCY_CODE', 'FIRST_PURCHASES', 'FIRST_PURCHASES_UNITS',
#        'FIRST_PURCHASES_ORIGINAL_PRICE', 'FIRST_PURCHASES_GROSS_DISCOUNT',
#        'ALL_PURCHASES', 'ALL_PURCHASES_UNITS', 'ALL_PURCHASES_ORIGINAL_PRICE',
#        'ALL_PURCHASES_GROSS_DISCOUNT', 'GOOGLE_PAID_SEARCH_SPEND',
#        'GOOGLE_SHOPPING_SPEND', 'GOOGLE_PMAX_SPEND', 'GOOGLE_DISPLAY_SPEND',
#        'GOOGLE_VIDEO_SPEND', 'META_FACEBOOK_SPEND', 'META_INSTAGRAM_SPEND',
#        'META_OTHER_SPEND', 'TIKTOK_SPEND', 'GOOGLE_PAID_SEARCH_CLICKS',
#        'GOOGLE_SHOPPING_CLICKS', 'GOOGLE_PMAX_CLICKS', 'GOOGLE_DISPLAY_CLICKS',
#        'GOOGLE_VIDEO_CLICKS', 'META_FACEBOOK_CLICKS', 'META_INSTAGRAM_CLICKS',
#        'META_OTHER_CLICKS', 'TIKTOK_CLICKS', 'GOOGLE_PAID_SEARCH_IMPRESSIONS',
#        'GOOGLE_SHOPPING_IMPRESSIONS', 'GOOGLE_PMAX_IMPRESSIONS',
#        'GOOGLE_DISPLAY_IMPRESSIONS', 'GOOGLE_VIDEO_IMPRESSIONS',
#        'META_FACEBOOK_IMPRESSIONS', 'META_INSTAGRAM_IMPRESSIONS',
#        'META_OTHER_IMPRESSIONS', 'TIKTOK_IMPRESSIONS', 'DIRECT_CLICKS',
#        'BRANDED_SEARCH_CLICKS', 'ORGANIC_SEARCH_CLICKS', 'EMAIL_CLICKS',
#        'REFERRAL_CLICKS', 'ALL_OTHER_CLICKS'],
#       dtype='str')

# %%
google_spend_cols = [col for col in df.columns if col.startswith("GOOGLE_") and col.endswith("_SPEND")]
df["GOOGLE_TOTAL_SPEND"] = df[google_spend_cols].fillna(0).sum(axis=1)

df[["GOOGLE_TOTAL_SPEND"] + google_spend_cols].head()
# Out:
#    GOOGLE_TOTAL_SPEND  GOOGLE_PAID_SEARCH_SPEND  GOOGLE_SHOPPING_SPEND  \
# 0          205.528905                       NaN                    NaN
# 1          277.082025                       NaN                    NaN
# 2          427.436429                       NaN                    NaN
# 3          382.472798                     35.24                    NaN
# 4          353.352971                     38.40                    NaN
#
#    GOOGLE_PMAX_SPEND  GOOGLE_DISPLAY_SPEND  GOOGLE_VIDEO_SPEND
# 0         205.528905                   NaN                 NaN
# 1         277.082025                   NaN                 NaN
# 2         427.436429                   NaN                 NaN
# 3         347.232798                   NaN                 NaN
# 4         314.952971                   NaN                 NaN

# %%
meta_spend_cols = [col for col in df.columns if col.startswith("META_") and col.endswith("_SPEND")]
df["META_TOTAL_SPEND"] = df[meta_spend_cols].fillna(0).sum(axis=1)

df[["META_TOTAL_SPEND"] + meta_spend_cols].head()
# Out:
#    META_TOTAL_SPEND  META_FACEBOOK_SPEND  META_INSTAGRAM_SPEND  \
# 0            233.75               233.75                   NaN
# 1            248.84               248.84                   NaN
# 2            274.51               274.51                   NaN
# 3            270.06               270.06                   NaN
# 4            257.62               257.62                   NaN
#
#    META_OTHER_SPEND
# 0               NaN
# 1               NaN
# 2               NaN
# 3               NaN
# 4               NaN

# %%
currency_code_counts = df["CURRENCY_CODE"].value_counts(dropna=False)
currency_code_counts
# Out:
# CURRENCY_CODE
# GBP    55598
# USD    33799
# EUR    21965
# AUD     9375
# CAD     3401
# HKD     1840
# NZD     1285
# JPY     1255
# DKK     1142
# CLP      923
# SEK      571
# NOK      571
# CHF      569
# ZAR      465
# Name: count, dtype: int64

# %%
import pandas as pd
import requests
import time
import numpy as np
from concurrent.futures import ThreadPoolExecutor, as_completed

df["DATE_DAY"] = pd.to_datetime(df["DATE_DAY"]).dt.date

# 2) Pick monetary columns to convert
money_cols = [
    c for c in df.columns
    if c.endswith("_SPEND") or "PRICE" in c or "DISCOUNT" in c
]
print(f"Selected {len(money_cols)} monetary columns for conversion.")

# 3) Build FX rate lookup: (date, currency) -> USD rate
pairs = df[["DATE_DAY", "CURRENCY_CODE"]].drop_duplicates()
fx = {}
print(f"Preparing to fetch FX rates for {len(pairs)} unique (date, currency) pairs.")

# USD rows require no API call
usd_pairs = pairs[pairs["CURRENCY_CODE"] == "USD"]
for d, c in usd_pairs.itertuples(index=False):
    fx[(d, c)] = 1.0
print(f"Mapped {len(usd_pairs)} USD pairs without API calls.")

non_usd_pairs = [
    (d, c)
    for d, c in pairs.itertuples(index=False)
    if c != "USD" and pd.notna(c)
]
print(f"Calling FX API for {len(non_usd_pairs)} non-USD pairs in parallel...")

def fetch_rate(d, c, retries=3):
    url = f"https://api.frankfurter.app/{d}?from={c}&to=USD"
    for attempt in range(1, retries + 1):
        try:
            r = requests.get(url, timeout=20)
            r.raise_for_status()
            rate = r.json().get("rates", {}).get("USD")
            if rate is None:
                return d, c, None, url, "missing_rate"
            return d, c, float(rate), url, None
        except requests.HTTPError as e:
            status_code = e.response.status_code if e.response is not None else None
            # Frankfurter returns 404 for unsupported currencies (for example CLP).
            if status_code == 404:
                return d, c, None, url, "unsupported_or_missing_on_source"
            if attempt == retries:
                return d, c, None, url, f"http_{status_code}"
            time.sleep(0.5 * attempt)
        except Exception as e:
            if attempt == retries:
                return d, c, None, url, f"exception: {e}"
            time.sleep(0.5 * attempt)

failed_pairs = []
max_workers = min(16, max(1, len(non_usd_pairs)))
if non_usd_pairs:
    with ThreadPoolExecutor(max_workers=max_workers) as executor:
        futures = {executor.submit(fetch_rate, d, c): (d, c) for d, c in non_usd_pairs}
        total = len(futures)
        for i, future in enumerate(as_completed(futures), start=1):
            d, c = futures[future]
            d, c, rate, url, error_reason = future.result()
            if rate is None:
                failed_pairs.append((d, c, error_reason, url))
                print(f"[{i}/{total}] WARNING: no FX rate for {c} on {d} ({error_reason})")
                continue
            fx[(d, c)] = rate
            print(f"[{i}/{total}] Retrieved rate: 1 {c} = {rate} USD ({d})")

if failed_pairs:
    print(f"WARNING: Failed to resolve {len(failed_pairs)} FX pairs. Those rows will remain unconverted.")
    preview = failed_pairs[:5]
    for d, c, reason, _ in preview:
        print(f" - {d} {c}: {reason}")

# 4) Apply conversion
print("Applying FX rates to dataframe...")
pair_index = pd.MultiIndex.from_frame(df[["DATE_DAY", "CURRENCY_CODE"]])
df["FX_TO_USD"] = pair_index.map(fx)
print("FX_TO_USD column created.")

missing_fx_rows = int(df["FX_TO_USD"].isna().sum())
if missing_fx_rows:
    print(f"WARNING: {missing_fx_rows} rows have no FX rate and were not converted.")

# Vectorized conversion is faster than per-column loops
usd_cols = [f"{col}_USD" for col in money_cols]
df[usd_cols] = df[money_cols].mul(df["FX_TO_USD"], axis=0)
print(f"Created {len(usd_cols)} *_USD columns.")

# Overwrite originals only for rows with a valid FX rate
valid_mask = df["FX_TO_USD"].notna()
df.loc[valid_mask, money_cols] = df.loc[valid_mask, money_cols].mul(
    df.loc[valid_mask, "FX_TO_USD"], axis=0
)
print("Original monetary columns converted to USD values where FX was available.")

# Only mark rows as USD if conversion happened
df["CURRENCY_CODE"] = np.where(valid_mask, "USD", df["CURRENCY_CODE"])
print("Currency normalization complete for successfully converted rows.")
# Out:
# Selected 15 monetary columns for conversion.
# Preparing to fetch FX rates for 14796 unique (date, currency) pairs.
# Mapped 1753 USD pairs without API calls.
# Calling FX API for 13043 non-USD pairs in parallel...
# [1/13043] Retrieved rate: 1 GBP = 1.3086 USD (2022-04-06)
# [2/13043] Retrieved rate: 1 GBP = 1.3024 USD (2022-04-11)
# [3/13043] Retrieved rate: 1 GBP = 1.3 USD (2022-04-13)
# [4/13043] Retrieved rate: 1 GBP = 1.303 USD (2022-04-08)
# [5/13043] Retrieved rate: 1 GBP = 1.3121 USD (2022-04-14)
# [6/13043] Retrieved rate: 1 GBP = 1.3134 USD (2022-04-03)
# [7/13043] Retrieved rate: 1 GBP = 1.3123 USD (2022-03-31)
# [8/13043] Retrieved rate: 1 GBP = 1.303 USD (2022-04-10)
# [9/13043] Retrieved rate: 1 GBP = 1.3118 USD (2022-04-04)
# [10/13043] Retrieved rate: 1 GBP = 1.3081 USD (2022-04-07)
# [11/13043] Retrieved rate: 1 GBP = 1.3138 USD (2022-04-05)
# [12/13043] Retrieved rate: 1 GBP = 1.303 USD (2022-04-09)
# [13/13043] Retrieved rate: 1 GBP = 1.3134 USD (2022-04-01)
# [14/13043] Retrieved rate: 1 GBP = 1.3157 USD (2022-03-30)
# [15/13043] Retrieved rate: 1 GBP = 1.3014 USD (2022-04-12)
# [16/13043] Retrieved rate: 1 GBP = 1.3134 USD (2022-04-02)
# [17/13043] Retrieved rate: 1 GBP = 1.3121 USD (2022-04-15)
# [18/13043] Retrieved rate: 1 GBP = 1.3121 USD (2022-04-16)
# [19/13043] Retrieved rate: 1 GBP = 1.3121 USD (2022-04-18)
# [20/13043] Retrieved rate: 1 GBP = 1.3054 USD (2022-04-20)
# [21/13043] Retrieved rate: 1 GBP = 1.2889 USD (2022-04-24)
# [22/13043] Retrieved rate: 1 GBP = 1.243 USD (2022-04-28)
# [23/13043] Retrieved rate: 1 GBP = 1.2889 USD (2022-04-22)
# [24/13043] Retrieved rate: 1 GBP = 1.2889 USD (2022-04-23)
# [25/13043] Retrieved rate: 1 GBP = 1.3023 USD (2022-04-19)
# [26/13043] Retrieved rate: 1 GBP = 1.2561 USD (2022-04-29)
# [27/13043] Retrieved rate: 1 GBP = 1.3121 USD (2022-04-17)
# [28/13043] Retrieved rate: 1 GBP = 1.2743 USD (2022-04-25)
# [29/13043] Retrieved rate: 1 GBP = 1.2561 USD (2022-04-30)
# [30/13043] Retrieved rate: 1 GBP = 1.2687 USD (2022-04-26)
# [31/13043] Retrieved rate: 1 GBP = 1.2567 USD (2022-04-27)
# [32/13043] Retrieved rate: 1 GBP = 1.3035 USD (2022-04-21)
# [33/13043] Retrieved rate: 1 GBP = 1.2547 USD (2022-05-03)
# [34/13043] Retrieved rate: 1 GBP = 1.2561 USD (2022-05-01)
# [35/13043] Retrieved rate: 1 GBP = 1.2557 USD (2022-05-02)
# [36/13043] Retrieved rate: 1 GBP = 1.2508 USD (2022-05-04)
# [37/13043] Retrieved rate: 1 GBP = 1.2405 USD (2022-05-05)
# [38/13043] Retrieved rate: 1 GBP = 1.2345 USD (2022-05-06)
# [39/13043] Retrieved rate: 1 GBP = 1.2345 USD (2022-05-07)
# [40/13043] Retrieved rate: 1 GBP = 1.2388 USD (2022-05-09)
# [41/13043] Retrieved rate: 1 GBP = 1.2345 USD (2022-05-08)
# [42/13043] Retrieved rate: 1 GBP = 1.2201 USD (2022-05-14)
# [43/13043] Retrieved rate: 1 GBP = 1.233 USD (2022-05-10)
# [44/13043] Retrieved rate: 1 GBP = 1.2201 USD (2022-05-13)
# [45/13043] Retrieved rate: 1 GBP = 1.2203 USD (2022-05-12)
# [46/13043] Retrieved rate: 1 GBP = 1.2255 USD (2022-05-16)
# [47/13043] Retrieved rate: 1 GBP = 1.2201 USD (2022-05-15)
# [48/13043] Retrieved rate: 1 GBP = 1.2358 USD (2022-05-11)
# [49/13043] Retrieved rate: 1 GBP = 1.2489 USD (2022-05-17)
# [50/13043] Retrieved rate: 1 GBP = 1.2422 USD (2022-05-19)
# [51/13043] Retrieved rate: 1 GBP = 1.2428 USD (2022-05-18)
# [52/13043] Retrieved rate: 1 GBP = 1.247 USD (2022-05-20)
# [53/13043] Retrieved rate: 1 GBP = 1.247 USD (2022-05-21)
# [54/13043] Retrieved rate: 1 GBP = 1.247 USD (2022-05-22)
# [55/13043] Retrieved rate: 1 GBP = 1.2572 USD (2022-05-23)
# [56/13043] Retrieved rate: 1 GBP = 1.2501 USD (2022-05-24)
# [57/13043] Retrieved rate: 1 GBP = 1.2493 USD (2022-05-25)
# [58/13043] Retrieved rate: 1 GBP = 1.2574 USD (2022-05-26)
# [59/13043] Retrieved rate: 1 GBP = 1.2633 USD (2022-05-27)
# [60/13043] Retrieved rate: 1 GBP = 1.2583 USD (2022-05-31)
# [61/13043] Retrieved rate: 1 GBP = 1.2633 USD (2022-05-28)
# [62/13043] Retrieved rate: 1 GBP = 1.2579 USD (2022-06-01)
# [63/13043] Retrieved rate: 1 GBP = 1.2641 USD (2022-05-30)
# [64/13043] Retrieved rate: 1 GBP = 1.2633 USD (2022-05-29)
# [65/13043] Retrieved rate: 1 GBP = 1.2561 USD (2022-06-03)
# [66/13043] Retrieved rate: 1 GBP = 1.255 USD (2022-06-02)
# [67/13043] Retrieved rate: 1 GBP = 1.2561 USD (2022-06-04)
# [68/13043] Retrieved rate: 1 GBP = 1.2561 USD (2022-06-05)
# [69/13043] Retrieved rate: 1 GBP = 1.249 USD (2022-06-07)
# [70/13043] Retrieved rate: 1 GBP = 1.2558 USD (2022-06-06)
# [71/13043] Retrieved rate: 1 GBP = 1.2549 USD (2022-06-08)
# [72/13043] Retrieved rate: 1 GBP = 1.2542 USD (2022-06-09)
# [73/13043] Retrieved rate: 1 GBP = 1.2438 USD (2022-06-11)
# [74/13043] Retrieved rate: 1 GBP = 1.2438 USD (2022-06-10)
# [75/13043] Retrieved rate: 1 GBP = 1.2178 USD (2022-06-13)
# [76/13043] Retrieved rate: 1 GBP = 1.2438 USD (2022-06-12)
# [77/13043] Retrieved rate: 1 GBP = 1.2083 USD (2022-06-15)
# [78/13043] Retrieved rate: 1 GBP = 1.2072 USD (2022-06-14)
# [79/13043] Retrieved rate: 1 GBP = 1.2157 USD (2022-06-16)
# [80/13043] Retrieved rate: 1 GBP = 1.2264 USD (2022-06-17)
# [81/13043] Retrieved rate: 1 GBP = 1.2264 USD (2022-06-18)
# [82/13043] Retrieved rate: 1 GBP = 1.2264 USD (2022-06-19)
# [83/13043] Retrieved rate: 1 GBP = 1.2265 USD (2022-06-20)
# [84/13043] Retrieved rate: 1 GBP = 1.2266 USD (2022-06-21)
# [85/13043] Retrieved rate: 1 GBP = 1.2227 USD (2022-06-23)
# [86/13043] Retrieved rate: 1 GBP = 1.225 USD (2022-06-22)
# [87/13043] Retrieved rate: 1 GBP = 1.2265 USD (2022-06-27)
# [88/13043] Retrieved rate: 1 GBP = 1.227 USD (2022-06-24)
# [89/13043] Retrieved rate: 1 GBP = 1.227 USD (2022-06-26)
# [90/13043] Retrieved rate: 1 GBP = 1.227 USD (2022-06-25)
# [91/13043] Retrieved rate: 1 GBP = 1.2164 USD (2022-06-29)
# [92/13043] Retrieved rate: 1 GBP = 1.2031 USD (2022-07-01)
# [93/13043] Retrieved rate: 1 GBP = 1.223 USD (2022-06-28)
# [94/13043] Retrieved rate: 1 GBP = 1.2031 USD (2022-07-02)
# [95/13043] Retrieved rate: 1 GBP = 1.2103 USD (2022-06-30)
# [96/13043] Retrieved rate: 1 GBP = 1.2031 USD (2022-07-03)
# [97/13043] Retrieved rate: 1 GBP = 1.1878 USD (2022-07-06)
# [98/13043] Retrieved rate: 1 GBP = 1.1987 USD (2022-07-05)
# [99/13043] Retrieved rate: 1 GBP = 1.2163 USD (2022-07-04)
# [100/13043] Retrieved rate: 1 GBP = 1.1962 USD (2022-07-07)
# [101/13043] Retrieved rate: 1 GBP = 1.2015 USD (2022-07-09)
# [102/13043] Retrieved rate: 1 GBP = 1.2015 USD (2022-07-08)
# [103/13043] Retrieved rate: 1 GBP = 1.2015 USD (2022-07-10)
# [104/13043] Retrieved rate: 1 GBP = 1.1945 USD (2022-07-11)
# [105/13043] Retrieved rate: 1 GBP = 1.1839 USD (2022-07-12)
# [106/13043] Retrieved rate: 1 GBP = 1.1932 USD (2022-07-13)
# [107/13043] Retrieved rate: 1 GBP = 1.1832 USD (2022-07-14)
# [108/13043] Retrieved rate: 1 GBP = 1.1836 USD (2022-07-15)
# [109/13043] Retrieved rate: 1 GBP = 1.1836 USD (2022-07-16)
# [110/13043] Retrieved rate: 1 GBP = 1.201 USD (2022-07-19)
# [111/13043] Retrieved rate: 1 GBP = 1.196 USD (2022-07-18)
# [112/13043] Retrieved rate: 1 GBP = 1.1836 USD (2022-07-17)
# [113/13043] Retrieved rate: 1 GBP = 1.1974 USD (2022-07-20)
# [114/13043] Retrieved rate: 1 GBP = 1.1922 USD (2022-07-21)
# [115/13043] Retrieved rate: 1 GBP = 1.1968 USD (2022-07-22)
# [116/13043] Retrieved rate: 1 GBP = 1.1968 USD (2022-07-23)
# [117/13043] Retrieved rate: 1 GBP = 1.1968 USD (2022-07-24)
# [118/13043] Retrieved rate: 1 GBP = 1.1973 USD (2022-07-26)
# [119/13043] Retrieved rate: 1 GBP = 1.2066 USD (2022-07-27)
# [120/13043] Retrieved rate: 1 GBP = 1.2069 USD (2022-07-25)
# [121/13043] Retrieved rate: 1 GBP = 1.211 USD (2022-07-28)
# [122/13043] Retrieved rate: 1 GBP = 1.2142 USD (2022-07-29)
# [123/13043] Retrieved rate: 1 GBP = 1.2142 USD (2022-07-31)
# [124/13043] Retrieved rate: 1 GBP = 1.2142 USD (2022-07-30)
# [125/13043] Retrieved rate: 1 GBP = 1.222 USD (2022-08-02)
# [126/13043] Retrieved rate: 1 GBP = 1.219 USD (2022-08-03)
# [127/13043] Retrieved rate: 1 GBP = 1.2087 USD (2022-08-04)
# [128/13043] Retrieved rate: 1 GBP = 1.2143 USD (2022-08-06)
# [129/13043] Retrieved rate: 1 GBP = 1.2143 USD (2022-08-05)
# [130/13043] Retrieved rate: 1 GBP = 1.2226 USD (2022-08-01)
# [131/13043] Retrieved rate: 1 GBP = 1.2143 USD (2022-08-07)
# [132/13043] Retrieved rate: 1 GBP = 1.2118 USD (2022-08-08)
# [133/13043] Retrieved rate: 1 GBP = 1.2108 USD (2022-08-09)
# [134/13043] Retrieved rate: 1 GBP = 1.2141 USD (2022-08-12)
# [135/13043] Retrieved rate: 1 GBP = 1.2223 USD (2022-08-11)
# [136/13043] Retrieved rate: 1 GBP = 1.2117 USD (2022-08-10)
# [137/13043] Retrieved rate: 1 GBP = 1.2141 USD (2022-08-13)
# [138/13043] Retrieved rate: 1 GBP = 1.2083 USD (2022-08-15)
# [139/13043] Retrieved rate: 1 GBP = 1.2141 USD (2022-08-14)
# [140/13043] Retrieved rate: 1 GBP = 1.207 USD (2022-08-17)
# [141/13043] Retrieved rate: 1 GBP = 1.2029 USD (2022-08-16)
# [142/13043] Retrieved rate: 1 GBP = 1.2061 USD (2022-08-18)
# [143/13043] Retrieved rate: 1 GBP = 1.1837 USD (2022-08-19)
# [144/13043] Retrieved rate: 1 GBP = 1.1837 USD (2022-08-21)
# [145/13043] Retrieved rate: 1 GBP = 1.1837 USD (2022-08-20)
# [146/13043] Retrieved rate: 1 GBP = 1.1813 USD (2022-08-22)
# [147/13043] Retrieved rate: 1 GBP = 1.1828 USD (2022-08-25)
# [148/13043] Retrieved rate: 1 GBP = 1.177 USD (2022-08-23)
# [149/13043] Retrieved rate: 1 GBP = 1.1786 USD (2022-08-24)
# [150/13043] Retrieved rate: 1 GBP = 1.183 USD (2022-08-26)
# [151/13043] Retrieved rate: 1 GBP = 1.183 USD (2022-08-28)
# [152/13043] Retrieved rate: 1 GBP = 1.183 USD (2022-08-27)
# [153/13043] Retrieved rate: 1 GBP = 1.169 USD (2022-08-29)
# [154/13043] Retrieved rate: 1 GBP = 1.1716 USD (2022-08-30)
# [155/13043] Retrieved rate: 1 GBP = 1.1569 USD (2022-09-01)
# [156/13043] Retrieved rate: 1 GBP = 1.1556 USD (2022-09-02)
# [157/13043] Retrieved rate: 1 GBP = 1.1623 USD (2022-08-31)
# [158/13043] Retrieved rate: 1 GBP = 1.1556 USD (2022-09-03)
# [159/13043] Retrieved rate: 1 GBP = 1.1556 USD (2022-09-04)
# [160/13043] Retrieved rate: 1 GBP = 1.1579 USD (2022-09-06)
# [161/13043] Retrieved rate: 1 GBP = 1.1426 USD (2022-09-07)
# [162/13043] Retrieved rate: 1 GBP = 1.1487 USD (2022-09-05)
# [163/13043] Retrieved rate: 1 GBP = 1.155 USD (2022-09-08)
# [164/13043] Retrieved rate: 1 GBP = 1.1569 USD (2022-09-09)
# [165/13043] Retrieved rate: 1 GBP = 1.1569 USD (2022-09-10)
# [166/13043] Retrieved rate: 1 GBP = 1.1569 USD (2022-09-11)
# [167/13043] Retrieved rate: 1 GBP = 1.1702 USD (2022-09-12)
# [168/13043] Retrieved rate: 1 GBP = 1.1723 USD (2022-09-13)
# [169/13043] Retrieved rate: 1 GBP = 1.1549 USD (2022-09-14)
# [170/13043] Retrieved rate: 1 GBP = 1.1494 USD (2022-09-15)
# [171/13043] Retrieved rate: 1 GBP = 1.1389 USD (2022-09-17)
# [172/13043] Retrieved rate: 1 GBP = 1.1389 USD (2022-09-16)
# [173/13043] Retrieved rate: 1 GBP = 1.1389 USD (2022-09-18)
# [174/13043] Retrieved rate: 1 GBP = 1.138 USD (2022-09-19)
# [175/13043] Retrieved rate: 1 GBP = 1.1328 USD (2022-09-22)
# [176/13043] Retrieved rate: 1 GBP = 1.1059 USD (2022-09-23)
# [177/13043] Retrieved rate: 1 GBP = 1.1426 USD (2022-09-20)
# [178/13043] Retrieved rate: 1 GBP = 1.1343 USD (2022-09-21)
# [179/13043] Retrieved rate: 1 GBP = 1.1059 USD (2022-09-24)
# [180/13043] Retrieved rate: 1 GBP = 1.1059 USD (2022-09-25)
# [181/13043] Retrieved rate: 1 GBP = 1.0789 USD (2022-09-26)
# [182/13043] Retrieved rate: 1 GBP = 1.0803 USD (2022-09-27)
# [183/13043] Retrieved rate: 1 GBP = 1.0596 USD (2022-09-28)
# [184/13043] Retrieved rate: 1 GBP = 1.0847 USD (2022-09-29)
# [185/13043] Retrieved rate: 1 GBP = 1.104 USD (2022-09-30)
# [186/13043] Retrieved rate: 1 GBP = 1.104 USD (2022-10-01)
# [187/13043] Retrieved rate: 1 GBP = 1.1214 USD (2022-10-03)
# [188/13043] Retrieved rate: 1 GBP = 1.104 USD (2022-10-02)
# [189/13043] Retrieved rate: 1 GBP = 1.1333 USD (2022-10-04)
# [190/13043] Retrieved rate: 1 GBP = 1.1258 USD (2022-10-06)
# [191/13043] Retrieved rate: 1 GBP = 1.1352 USD (2022-10-05)
# [192/13043] Retrieved rate: 1 GBP = 1.1212 USD (2022-10-07)
# [193/13043] Retrieved rate: 1 GBP = 1.1212 USD (2022-10-09)
# [194/13043] Retrieved rate: 1 GBP = 1.1212 USD (2022-10-08)
# [195/13043] Retrieved rate: 1 GBP = 1.105 USD (2022-10-12)
# [196/13043] Retrieved rate: 1 GBP = 1.1086 USD (2022-10-11)
# [197/13043] Retrieved rate: 1 GBP = 1.1053 USD (2022-10-10)
# [198/13043] Retrieved rate: 1 GBP = 1.1257 USD (2022-10-13)
# [199/13043] Retrieved rate: 1 GBP = 1.1192 USD (2022-10-14)
# [200/13043] Retrieved rate: 1 GBP = 1.1192 USD (2022-10-16)
# [201/13043] Retrieved rate: 1 GBP = 1.1192 USD (2022-10-15)
# [202/13043] Retrieved rate: 1 GBP = 1.1292 USD (2022-10-17)
# [203/13043] Retrieved rate: 1 GBP = 1.124 USD (2022-10-19)
# [204/13043] Retrieved rate: 1 GBP = 1.1244 USD (2022-10-20)
# [205/13043] Retrieved rate: 1 GBP = 1.1314 USD (2022-10-18)
# [206/13043] Retrieved rate: 1 GBP = 1.1091 USD (2022-10-22)
# [207/13043] Retrieved rate: 1 GBP = 1.1091 USD (2022-10-21)
# [208/13043] Retrieved rate: 1 GBP = 1.1316 USD (2022-10-25)
# [209/13043] Retrieved rate: 1 GBP = 1.1091 USD (2022-10-23)
# [210/13043] Retrieved rate: 1 GBP = 1.1314 USD (2022-10-24)
# [211/13043] Retrieved rate: 1 GBP = 1.1574 USD (2022-10-26)
# [212/13043] Retrieved rate: 1 GBP = 1.1571 USD (2022-10-27)
# [213/13043] Retrieved rate: 1 GBP = 1.1555 USD (2022-10-28)
# [214/13043] Retrieved rate: 1 GBP = 1.1555 USD (2022-10-29)
# [215/13043] Retrieved rate: 1 GBP = 1.1555 USD (2022-10-30)
# [216/13043] Retrieved rate: 1 GBP = 1.1513 USD (2022-10-31)
# [217/13043] Retrieved rate: 1 GBP = 1.1558 USD (2022-11-01)
# [218/13043] Retrieved rate: 1 GBP = 1.1508 USD (2022-11-02)
# [219/13043] Retrieved rate: 1 GBP = 1.1285 USD (2022-11-06)
# [220/13043] Retrieved rate: 1 GBP = 1.1285 USD (2022-11-04)
# [221/13043] Retrieved rate: 1 GBP = 1.1181 USD (2022-11-03)
# [222/13043] Retrieved rate: 1 GBP = 1.1285 USD (2022-11-05)
# [223/13043] Retrieved rate: 1 GBP = 1.1468 USD (2022-11-07)
# [224/13043] Retrieved rate: 1 GBP = 1.144 USD (2022-11-08)
# [225/13043] Retrieved rate: 1 GBP = 1.1437 USD (2022-11-09)
# [226/13043] Retrieved rate: 1 GBP = 1.1402 USD (2022-11-10)
# [227/13043] Retrieved rate: 1 GBP = 1.1775 USD (2022-11-11)
# [228/13043] Retrieved rate: 1 GBP = 1.1775 USD (2022-11-12)
# [229/13043] Retrieved rate: 1 GBP = 1.1775 USD (2022-11-13)
# [230/13043] Retrieved rate: 1 GBP = 1.1896 USD (2022-11-15)
# [231/13043] Retrieved rate: 1 GBP = 1.1902 USD (2022-11-16)
# [232/13043] Retrieved rate: 1 GBP = 1.1791 USD (2022-11-14)
# [233/13043] Retrieved rate: 1 GBP = 1.1797 USD (2022-11-17)
# [234/13043] Retrieved rate: 1 GBP = 1.1906 USD (2022-11-18)
# [235/13043] Retrieved rate: 1 GBP = 1.1906 USD (2022-11-19)
# [236/13043] Retrieved rate: 1 GBP = 1.1906 USD (2022-11-20)
# [237/13043] Retrieved rate: 1 GBP = 1.1805 USD (2022-11-21)
# [238/13043] Retrieved rate: 1 GBP = 1.1897 USD (2022-11-22)
# [239/13043] Retrieved rate: 1 GBP = 1.2118 USD (2022-11-24)
# [240/13043] Retrieved rate: 1 GBP = 1.1955 USD (2022-11-23)
# [241/13043] Retrieved rate: 1 GBP = 1.208 USD (2022-11-25)
# [242/13043] Retrieved rate: 1 GBP = 1.208 USD (2022-11-26)
# [243/13043] Retrieved rate: 1 GBP = 1.208 USD (2022-11-27)
# [244/13043] Retrieved rate: 1 GBP = 1.2081 USD (2022-11-28)
# [245/13043] Retrieved rate: 1 GBP = 1.2023 USD (2022-11-29)
# [246/13043] Retrieved rate: 1 GBP = 1.1997 USD (2022-11-30)
# [247/13043] Retrieved rate: 1 GBP = 1.2274 USD (2022-12-02)
# [248/13043] Retrieved rate: 1 GBP = 1.2196 USD (2022-12-01)
# [249/13043] Retrieved rate: 1 GBP = 1.2274 USD (2022-12-03)
# [250/13043] Retrieved rate: 1 GBP = 1.2274 USD (2022-12-04)
# [251/13043] Retrieved rate: 1 GBP = 1.2298 USD (2022-12-05)
# [252/13043] Retrieved rate: 1 GBP = 1.2204 USD (2022-12-06)
# [253/13043] Retrieved rate: 1 GBP = 1.2195 USD (2022-12-08)
# [254/13043] Retrieved rate: 1 GBP = 1.2285 USD (2022-12-10)
# [255/13043] Retrieved rate: 1 GBP = 1.2185 USD (2022-12-07)
# [256/13043] Retrieved rate: 1 GBP = 1.2285 USD (2022-12-09)
# [257/13043] Retrieved rate: 1 GBP = 1.2281 USD (2022-12-12)
# [258/13043] Retrieved rate: 1 GBP = 1.2285 USD (2022-12-11)
# [259/13043] Retrieved rate: 1 GBP = 1.2366 USD (2022-12-14)
# [260/13043] Retrieved rate: 1 GBP = 1.2297 USD (2022-12-13)
# [261/13043] Retrieved rate: 1 GBP = 1.2173 USD (2022-12-16)
# [262/13043] Retrieved rate: 1 GBP = 1.2173 USD (2022-12-18)
# [263/13043] Retrieved rate: 1 GBP = 1.2322 USD (2022-12-15)
# [264/13043] Retrieved rate: 1 GBP = 1.2109 USD (2022-12-20)
# [265/13043] Retrieved rate: 1 GBP = 1.2173 USD (2022-12-17)
# [266/13043] Retrieved rate: 1 GBP = 1.2165 USD (2022-12-19)
# [267/13043] Retrieved rate: 1 GBP = 1.2134 USD (2022-12-21)
# [268/13043] Retrieved rate: 1 GBP = 1.2066 USD (2022-12-25)
# [269/13043] Retrieved rate: 1 GBP = 1.2066 USD (2022-12-24)
# [270/13043] Retrieved rate: 1 GBP = 1.205 USD (2022-12-22)
# [271/13043] Retrieved rate: 1 GBP = 1.2066 USD (2022-12-23)
# [272/13043] Retrieved rate: 1 GBP = 1.2066 USD (2022-12-26)
# [273/13043] Retrieved rate: 1 GBP = 1.2083 USD (2022-12-28)
# [274/13043] Retrieved rate: 1 GBP = 1.2027 USD (2022-12-27)
# [275/13043] Retrieved rate: 1 GBP = 1.2026 USD (2022-12-29)
# [276/13043] Retrieved rate: 1 GBP = 1.2026 USD (2022-12-30)
# [277/13043] Retrieved rate: 1 GBP = 1.2026 USD (2022-12-31)
# [278/13043] Retrieved rate: 1 GBP = 1.2053 USD (2023-01-02)
# [279/13043] Retrieved rate: 1 GBP = 1.2026 USD (2023-01-01)
# [280/13043] Retrieved rate: 1 GBP = 1.2005 USD (2023-01-05)
# [281/13043] Retrieved rate: 1 GBP = 1.1976 USD (2023-01-03)
# [282/13043] Retrieved rate: 1 GBP = 1.2034 USD (2023-01-04)
# [283/13043] Retrieved rate: 1 GBP = 1.1868 USD (2023-01-06)
# [284/13043] Retrieved rate: 1 GBP = 1.2148 USD (2023-01-09)
# [285/13043] Retrieved rate: 1 GBP = 1.1868 USD (2023-01-07)
# [286/13043] Retrieved rate: 1 GBP = 1.1868 USD (2023-01-08)
# [287/13043] Retrieved rate: 1 GBP = 1.214 USD (2023-01-10)
# [288/13043] Retrieved rate: 1 GBP = 1.212 USD (2023-01-11)
# [289/13043] Retrieved rate: 1 GBP = 1.2146 USD (2023-01-12)
# [290/13043] Retrieved rate: 1 GBP = 1.2178 USD (2023-01-13)
# [291/13043] Retrieved rate: 1 GBP = 1.2178 USD (2023-01-14)
# [292/13043] Retrieved rate: 1 GBP = 1.2178 USD (2023-01-15)
# [293/13043] Retrieved rate: 1 GBP = 1.2181 USD (2023-01-16)
# [294/13043] Retrieved rate: 1 GBP = 1.2239 USD (2023-01-17)
# [295/13043] Retrieved rate: 1 GBP = 1.2383 USD (2023-01-18)
# [296/13043] Retrieved rate: 1 GBP = 1.2358 USD (2023-01-20)
# [297/13043] Retrieved rate: 1 GBP = 1.2339 USD (2023-01-19)
# [298/13043] Retrieved rate: 1 GBP = 1.2358 USD (2023-01-22)
# [299/13043] Retrieved rate: 1 GBP = 1.2358 USD (2023-01-21)
# [300/13043] Retrieved rate: 1 GBP = 1.2327 USD (2023-01-25)
# [301/13043] Retrieved rate: 1 GBP = 1.2358 USD (2023-01-23)
# [302/13043] Retrieved rate: 1 GBP = 1.2287 USD (2023-01-24)
# [303/13043] Retrieved rate: 1 GBP = 1.2388 USD (2023-01-26)
# [304/13043] Retrieved rate: 1 GBP = 1.2363 USD (2023-01-27)
# [305/13043] Retrieved rate: 1 GBP = 1.2363 USD (2023-01-29)
# [306/13043] Retrieved rate: 1 GBP = 1.2393 USD (2023-01-30)
# [307/13043] Retrieved rate: 1 GBP = 1.2322 USD (2023-02-01)
# [308/13043] Retrieved rate: 1 GBP = 1.2363 USD (2023-01-28)
# [309/13043] Retrieved rate: 1 GBP = 1.2254 USD (2023-02-03)
# [310/13043] Retrieved rate: 1 GBP = 1.23 USD (2023-01-31)
# [311/13043] Retrieved rate: 1 GBP = 1.2306 USD (2023-02-02)
# [312/13043] Retrieved rate: 1 GBP = 1.2254 USD (2023-02-04)
# [313/13043] Retrieved rate: 1 GBP = 1.2254 USD (2023-02-05)
# [314/13043] Retrieved rate: 1 GBP = 1.207 USD (2023-02-06)
# [315/13043] Retrieved rate: 1 GBP = 1.1977 USD (2023-02-07)
# [316/13043] Retrieved rate: 1 GBP = 1.2089 USD (2023-02-08)
# [317/13043] Retrieved rate: 1 GBP = 1.2169 USD (2023-02-09)
# [318/13043] Retrieved rate: 1 GBP = 1.21 USD (2023-02-11)
# [319/13043] Retrieved rate: 1 GBP = 1.21 USD (2023-02-10)
# [320/13043] Retrieved rate: 1 GBP = 1.2105 USD (2023-02-13)
# [321/13043] Retrieved rate: 1 GBP = 1.21 USD (2023-02-12)
# [322/13043] Retrieved rate: 1 GBP = 1.2209 USD (2023-02-14)
# [323/13043] Retrieved rate: 1 GBP = 1.2046 USD (2023-02-15)
# [324/13043] Retrieved rate: 1 GBP = 1.1953 USD (2023-02-19)
# [325/13043] Retrieved rate: 1 GBP = 1.2038 USD (2023-02-16)
# [326/13043] Retrieved rate: 1 GBP = 1.1953 USD (2023-02-18)
# [327/13043] Retrieved rate: 1 GBP = 1.1953 USD (2023-02-17)
# [328/13043] Retrieved rate: 1 GBP = 1.2029 USD (2023-02-20)
# [329/13043] Retrieved rate: 1 GBP = 1.2129 USD (2023-02-21)
# [330/13043] Retrieved rate: 1 GBP = 1.2103 USD (2023-02-22)
# [331/13043] Retrieved rate: 1 GBP = 1.2044 USD (2023-02-23)
# [332/13043] Retrieved rate: 1 GBP = 1.1978 USD (2023-02-24)
# [333/13043] Retrieved rate: 1 GBP = 1.2062 USD (2023-03-01)
# [334/13043] Retrieved rate: 1 GBP = 1.1983 USD (2023-02-27)
# [335/13043] Retrieved rate: 1 GBP = 1.2108 USD (2023-02-28)
# [336/13043] Retrieved rate: 1 GBP = 1.1945 USD (2023-03-02)
# [337/13043] Retrieved rate: 1 GBP = 1.1978 USD (2023-02-25)
# [338/13043] Retrieved rate: 1 GBP = 1.1978 USD (2023-02-26)
# [339/13043] Retrieved rate: 1 GBP = 1.2012 USD (2023-03-06)
# [340/13043] Retrieved rate: 1 GBP = 1.1987 USD (2023-03-07)
# [341/13043] Retrieved rate: 1 GBP = 1.199 USD (2023-03-04)
# [342/13043] Retrieved rate: 1 GBP = 1.199 USD (2023-03-03)
# [343/13043] Retrieved rate: 1 GBP = 1.1838 USD (2023-03-08)
# [344/13043] Retrieved rate: 1 GBP = 1.199 USD (2023-03-05)
# [345/13043] Retrieved rate: 1 GBP = 1.1883 USD (2023-03-09)
# [346/13043] Retrieved rate: 1 GBP = 1.1994 USD (2023-03-11)
# [347/13043] Retrieved rate: 1 GBP = 1.1994 USD (2023-03-10)
# [348/13043] Retrieved rate: 1 GBP = 1.1994 USD (2023-03-12)
# [349/13043] Retrieved rate: 1 GBP = 1.2115 USD (2023-03-13)
# [350/13043] Retrieved rate: 1 GBP = 1.2142 USD (2023-03-18)
# [351/13043] Retrieved rate: 1 GBP = 1.2194 USD (2023-03-14)
# [352/13043] Retrieved rate: 1 GBP = 1.2142 USD (2023-03-17)
# [353/13043] Retrieved rate: 1 GBP = 1.2064 USD (2023-03-16)
# [354/13043] Retrieved rate: 1 GBP = 1.2092 USD (2023-03-15)
# [355/13043] Retrieved rate: 1 GBP = 1.2142 USD (2023-03-19)
# [356/13043] Retrieved rate: 1 GBP = 1.224 USD (2023-03-20)
# [357/13043] Retrieved rate: 1 GBP = 1.2241 USD (2023-03-21)
# [358/13043] Retrieved rate: 1 GBP = 1.2289 USD (2023-03-23)
# [359/13043] Retrieved rate: 1 GBP = 1.2219 USD (2023-03-24)
# [360/13043] Retrieved rate: 1 GBP = 1.2266 USD (2023-03-22)
# [361/13043] Retrieved rate: 1 GBP = 1.2219 USD (2023-03-25)
# [362/13043] Retrieved rate: 1 GBP = 1.2267 USD (2023-03-27)
# [363/13043] Retrieved rate: 1 GBP = 1.2219 USD (2023-03-26)
# [364/13043] Retrieved rate: 1 GBP = 1.2328 USD (2023-03-28)
# [365/13043] Retrieved rate: 1 GBP = 1.2328 USD (2023-03-29)
# [366/13043] Retrieved rate: 1 GBP = 1.2369 USD (2023-04-01)
# [367/13043] Retrieved rate: 1 GBP = 1.2347 USD (2023-03-30)
# [368/13043] Retrieved rate: 1 GBP = 1.2382 USD (2023-04-03)
# [369/13043] Retrieved rate: 1 GBP = 1.2369 USD (2023-04-02)
# [370/13043] Retrieved rate: 1 GBP = 1.2369 USD (2023-03-31)
# [371/13043] Retrieved rate: 1 GBP = 1.2482 USD (2023-04-04)
# [372/13043] Retrieved rate: 1 GBP = 1.2475 USD (2023-04-06)
# [373/13043] Retrieved rate: 1 GBP = 1.2475 USD (2023-04-07)
# [374/13043] Retrieved rate: 1 GBP = 1.2475 USD (2023-04-09)
# [375/13043] Retrieved rate: 1 GBP = 1.2476 USD (2023-04-05)
# [376/13043] Retrieved rate: 1 GBP = 1.2475 USD (2023-04-08)
# [377/13043] Retrieved rate: 1 GBP = 1.2475 USD (2023-04-10)
# [378/13043] Retrieved rate: 1 GBP = 1.2406 USD (2023-04-12)
# [379/13043] Retrieved rate: 1 GBP = 1.2429 USD (2023-04-11)
# [380/13043] Retrieved rate: 1 GBP = 1.2509 USD (2023-04-13)
# [381/13043] Retrieved rate: 1 GBP = 1.2502 USD (2023-04-14)
# [382/13043] Retrieved rate: 1 GBP = 1.2502 USD (2023-04-16)
# [383/13043] Retrieved rate: 1 GBP = 1.2502 USD (2023-04-15)
# [384/13043] Retrieved rate: 1 GBP = 1.2448 USD (2023-04-18)
# [385/13043] Retrieved rate: 1 GBP = 1.2409 USD (2023-04-19)
# [386/13043] Retrieved rate: 1 GBP = 1.2426 USD (2023-04-17)
# [387/13043] Retrieved rate: 1 GBP = 1.2415 USD (2023-04-20)
# [388/13043] Retrieved rate: 1 GBP = 1.2395 USD (2023-04-21)
# [389/13043] Retrieved rate: 1 GBP = 1.2434 USD (2023-04-25)
# [390/13043] Retrieved rate: 1 GBP = 1.2487 USD (2023-04-27)
# [391/13043] Retrieved rate: 1 GBP = 1.2395 USD (2023-04-23)
# [392/13043] Retrieved rate: 1 GBP = 1.2437 USD (2023-04-24)
# [393/13043] Retrieved rate: 1 GBP = 1.2395 USD (2023-04-22)
# [394/13043] Retrieved rate: 1 GBP = 1.2465 USD (2023-04-26)
# [395/13043] Retrieved rate: 1 GBP = 1.2471 USD (2023-04-28)
# [396/13043] Retrieved rate: 1 GBP = 1.2471 USD (2023-04-29)
# [397/13043] Retrieved rate: 1 GBP = 1.2471 USD (2023-04-30)
# [398/13043] Retrieved rate: 1 GBP = 1.2605 USD (2023-05-05)
# [399/13043] Retrieved rate: 1 GBP = 1.2471 USD (2023-05-01)
# [400/13043] Retrieved rate: 1 GBP = 1.2479 USD (2023-05-02)
# [401/13043] Retrieved rate: 1 GBP = 1.2582 USD (2023-05-04)
# [402/13043] Retrieved rate: 1 GBP = 1.2605 USD (2023-05-06)
# [403/13043] Retrieved rate: 1 GBP = 1.2511 USD (2023-05-03)
# [404/13043] Retrieved rate: 1 GBP = 1.2653 USD (2023-05-08)
# [405/13043] Retrieved rate: 1 GBP = 1.2605 USD (2023-05-07)
# [406/13043] Retrieved rate: 1 GBP = 1.2598 USD (2023-05-09)
# [407/13043] Retrieved rate: 1 GBP = 1.2517 USD (2023-05-12)
# [408/13043] Retrieved rate: 1 GBP = 1.2509 USD (2023-05-15)
# [409/13043] Retrieved rate: 1 GBP = 1.2593 USD (2023-05-11)
# [410/13043] Retrieved rate: 1 GBP = 1.2517 USD (2023-05-14)
# [411/13043] Retrieved rate: 1 GBP = 1.2613 USD (2023-05-10)
# [412/13043] Retrieved rate: 1 GBP = 1.2517 USD (2023-05-13)
# [413/13043] Retrieved rate: 1 GBP = 1.2516 USD (2023-05-16)
# [414/13043] Retrieved rate: 1 GBP = 1.2444 USD (2023-05-18)
# [415/13043] Retrieved rate: 1 GBP = 1.2446 USD (2023-05-21)
# [416/13043] Retrieved rate: 1 GBP = 1.2446 USD (2023-05-19)
# [417/13043] Retrieved rate: 1 GBP = 1.2446 USD (2023-05-20)
# [418/13043] Retrieved rate: 1 GBP = 1.2461 USD (2023-05-22)
# [419/13043] Retrieved rate: 1 GBP = 1.2462 USD (2023-05-17)
# [420/13043] Retrieved rate: 1 GBP = 1.2391 USD (2023-05-23)
# [421/13043] Retrieved rate: 1 GBP = 1.2398 USD (2023-05-24)
# [422/13043] Retrieved rate: 1 GBP = 1.2384 USD (2023-05-26)
# [423/13043] Retrieved rate: 1 GBP = 1.2369 USD (2023-05-25)
# [424/13043] Retrieved rate: 1 GBP = 1.2384 USD (2023-05-27)
# [425/13043] Retrieved rate: 1 GBP = 1.2384 USD (2023-05-28)
# [426/13043] Retrieved rate: 1 GBP = 1.2364 USD (2023-05-31)
# [427/13043] Retrieved rate: 1 GBP = 1.2344 USD (2023-05-29)
# [428/13043] Retrieved rate: 1 GBP = 1.244 USD (2023-05-30)
# [429/13043] Retrieved rate: 1 GBP = 1.2464 USD (2023-06-01)
# [430/13043] Retrieved rate: 1 GBP = 1.2525 USD (2023-06-03)
# [431/13043] Retrieved rate: 1 GBP = 1.2525 USD (2023-06-02)
# [432/13043] Retrieved rate: 1 GBP = 1.2525 USD (2023-06-04)
# [433/13043] Retrieved rate: 1 GBP = 1.2407 USD (2023-06-06)
# [434/13043] Retrieved rate: 1 GBP = 1.2466 USD (2023-06-07)
# [435/13043] Retrieved rate: 1 GBP = 1.2469 USD (2023-06-08)
# [436/13043] Retrieved rate: 1 GBP = 1.2384 USD (2023-06-05)
# [437/13043] Retrieved rate: 1 GBP = 1.2565 USD (2023-06-09)
# [438/13043] Retrieved rate: 1 GBP = 1.2565 USD (2023-06-11)
# [439/13043] Retrieved rate: 1 GBP = 1.2565 USD (2023-06-10)
# [440/13043] Retrieved rate: 1 GBP = 1.2572 USD (2023-06-13)
# [441/13043] Retrieved rate: 1 GBP = 1.2649 USD (2023-06-14)
# [442/13043] Retrieved rate: 1 GBP = 1.2564 USD (2023-06-12)
# [443/13043] Retrieved rate: 1 GBP = 1.2837 USD (2023-06-16)
# [444/13043] Retrieved rate: 1 GBP = 1.2646 USD (2023-06-15)
# [445/13043] Retrieved rate: 1 GBP = 1.2837 USD (2023-06-17)
# [446/13043] Retrieved rate: 1 GBP = 1.2809 USD (2023-06-19)
# [447/13043] Retrieved rate: 1 GBP = 1.2837 USD (2023-06-18)
# [448/13043] Retrieved rate: 1 GBP = 1.2757 USD (2023-06-20)
# [449/13043] Retrieved rate: 1 GBP = 1.2727 USD (2023-06-21)
# [450/13043] Retrieved rate: 1 GBP = 1.2733 USD (2023-06-23)
# [451/13043] Retrieved rate: 1 GBP = 1.2733 USD (2023-06-24)
# [452/13043] Retrieved rate: 1 GBP = 1.2756 USD (2023-06-22)
# [453/13043] Retrieved rate: 1 GBP = 1.2733 USD (2023-06-25)
# [454/13043] Retrieved rate: 1 GBP = 1.2713 USD (2023-06-26)
# [455/13043] Retrieved rate: 1 GBP = 1.2735 USD (2023-06-27)
# [456/13043] Retrieved rate: 1 GBP = 1.266 USD (2023-06-30)
# [457/13043] Retrieved rate: 1 GBP = 1.266 USD (2023-06-29)
# [458/13043] Retrieved rate: 1 GBP = 1.2657 USD (2023-06-28)
# [459/13043] Retrieved rate: 1 EUR = 1.0559 USD (2022-12-09)
# [460/13043] Retrieved rate: 1 EUR = 1.0559 USD (2022-12-10)
# [461/13043] Retrieved rate: 1 EUR = 1.0559 USD (2022-12-11)
# [462/13043] Retrieved rate: 1 EUR = 1.0545 USD (2022-12-13)
# [463/13043] Retrieved rate: 1 EUR = 1.0562 USD (2022-12-12)
# [464/13043] Retrieved rate: 1 EUR = 1.0649 USD (2022-12-14)
# [465/13043] Retrieved rate: 1 EUR = 1.0621 USD (2022-12-15)
# [466/13043] Retrieved rate: 1 EUR = 1.0619 USD (2022-12-17)
# [467/13043] Retrieved rate: 1 EUR = 1.0619 USD (2022-12-16)
# [468/13043] Retrieved rate: 1 EUR = 1.0636 USD (2022-12-21)
# [469/13043] Retrieved rate: 1 EUR = 1.0599 USD (2022-12-20)
# [470/13043] Retrieved rate: 1 EUR = 1.0598 USD (2022-12-19)
# [471/13043] Retrieved rate: 1 EUR = 1.0619 USD (2022-12-18)
# [472/13043] Retrieved rate: 1 EUR = 1.0633 USD (2022-12-22)
# [473/13043] Retrieved rate: 1 EUR = 1.0622 USD (2022-12-24)
# [474/13043] Retrieved rate: 1 EUR = 1.0622 USD (2022-12-23)
# [475/13043] Retrieved rate: 1 EUR = 1.0622 USD (2022-12-25)
# [476/13043] Retrieved rate: 1 EUR = 1.0622 USD (2022-12-26)
# [477/13043] Retrieved rate: 1 EUR = 1.0624 USD (2022-12-27)
# [478/13043] Retrieved rate: 1 EUR = 1.064 USD (2022-12-28)
# [479/13043] Retrieved rate: 1 EUR = 1.0649 USD (2022-12-29)
# [480/13043] Retrieved rate: 1 EUR = 1.0666 USD (2022-12-30)
# [481/13043] Retrieved rate: 1 EUR = 1.0666 USD (2023-01-01)
# [482/13043] Retrieved rate: 1 EUR = 1.0545 USD (2023-01-03)
# [483/13043] Retrieved rate: 1 EUR = 1.0666 USD (2022-12-31)
# [484/13043] Retrieved rate: 1 EUR = 1.0601 USD (2023-01-05)
# [485/13043] Retrieved rate: 1 EUR = 1.0683 USD (2023-01-02)
# [486/13043] Retrieved rate: 1 EUR = 1.0723 USD (2023-01-10)
# [487/13043] Retrieved rate: 1 EUR = 1.0599 USD (2023-01-04)
# [488/13043] Retrieved rate: 1 EUR = 1.05 USD (2023-01-06)
# [489/13043] Retrieved rate: 1 EUR = 1.05 USD (2023-01-07)
# [490/13043] Retrieved rate: 1 EUR = 1.05 USD (2023-01-08)
# [491/13043] Retrieved rate: 1 EUR = 1.0696 USD (2023-01-09)
# [492/13043] Retrieved rate: 1 EUR = 1.0747 USD (2023-01-11)
# [493/13043] Retrieved rate: 1 EUR = 1.0814 USD (2023-01-14)
# [494/13043] Retrieved rate: 1 EUR = 1.0772 USD (2023-01-12)
# [495/13043] Retrieved rate: 1 EUR = 1.0814 USD (2023-01-13)
# [496/13043] Retrieved rate: 1 EUR = 1.0812 USD (2023-01-16)
# [497/13043] Retrieved rate: 1 EUR = 1.0814 USD (2023-01-15)
# [498/13043] Retrieved rate: 1 EUR = 1.0843 USD (2023-01-17)
# [499/13043] Retrieved rate: 1 EUR = 1.0839 USD (2023-01-18)
# [500/13043] Retrieved rate: 1 EUR = 1.0815 USD (2023-01-19)
# [501/13043] Retrieved rate: 1 EUR = 1.0826 USD (2023-01-20)
# [502/13043] Retrieved rate: 1 EUR = 1.0858 USD (2023-01-24)
# [503/13043] Retrieved rate: 1 EUR = 1.0878 USD (2023-01-25)
# [504/13043] Retrieved rate: 1 EUR = 1.0826 USD (2023-01-22)
# [505/13043] Retrieved rate: 1 EUR = 1.0895 USD (2023-01-26)
# [506/13043] Retrieved rate: 1 EUR = 1.0826 USD (2023-01-21)
# [507/13043] Retrieved rate: 1 EUR = 1.0871 USD (2023-01-23)
# [508/13043] Retrieved rate: 1 EUR = 1.0865 USD (2023-01-29)
# [509/13043] Retrieved rate: 1 EUR = 1.0865 USD (2023-01-27)
# [510/13043] Retrieved rate: 1 EUR = 1.0865 USD (2023-01-28)
# [511/13043] Retrieved rate: 1 EUR = 1.0903 USD (2023-01-30)
# [512/13043] Retrieved rate: 1 EUR = 1.0894 USD (2023-02-01)
# [513/13043] Retrieved rate: 1 EUR = 1.0833 USD (2023-01-31)
# [514/13043] Retrieved rate: 1 EUR = 1.0988 USD (2023-02-02)
# [515/13043] Retrieved rate: 1 EUR = 1.0937 USD (2023-02-05)
# [516/13043] Retrieved rate: 1 EUR = 1.0937 USD (2023-02-03)
# [517/13043] Retrieved rate: 1 EUR = 1.0937 USD (2023-02-04)
# [518/13043] Retrieved rate: 1 EUR = 1.0776 USD (2023-02-06)
# [519/13043] Retrieved rate: 1 EUR = 1.0771 USD (2023-02-09)
# [520/13043] Retrieved rate: 1 EUR = 1.07 USD (2023-02-07)
# [521/13043] Retrieved rate: 1 EUR = 1.0735 USD (2023-02-08)
# [522/13043] Retrieved rate: 1 EUR = 1.069 USD (2023-02-10)
# [523/13043] Retrieved rate: 1 EUR = 1.069 USD (2023-02-12)
# [524/13043] Retrieved rate: 1 EUR = 1.0686 USD (2023-02-13)
# [525/13043] Retrieved rate: 1 EUR = 1.0759 USD (2023-02-14)
# [526/13043] Retrieved rate: 1 EUR = 1.07 USD (2023-02-15)
# [527/13043] Retrieved rate: 1 EUR = 1.069 USD (2023-02-11)
# [528/13043] Retrieved rate: 1 EUR = 1.0625 USD (2023-02-17)
# [529/13043] Retrieved rate: 1 EUR = 1.07 USD (2023-02-16)
# [530/13043] Retrieved rate: 1 EUR = 1.0674 USD (2023-02-20)
# [531/13043] Retrieved rate: 1 EUR = 1.0625 USD (2023-02-18)
# [532/13043] Retrieved rate: 1 EUR = 1.0625 USD (2023-02-19)
# [533/13043] Retrieved rate: 1 EUR = 1.0664 USD (2023-02-21)
# [534/13043] Retrieved rate: 1 EUR = 1.0644 USD (2023-02-22)
# [535/13043] Retrieved rate: 1 EUR = 1.0616 USD (2023-02-23)
# [536/13043] Retrieved rate: 1 EUR = 1.057 USD (2023-02-24)
# [537/13043] Retrieved rate: 1 EUR = 1.057 USD (2023-02-25)
# [538/13043] Retrieved rate: 1 EUR = 1.057 USD (2023-02-26)
# [539/13043] Retrieved rate: 1 EUR = 1.0554 USD (2023-02-27)
# [540/13043] Retrieved rate: 1 EUR = 1.0684 USD (2023-03-01)
# [541/13043] Retrieved rate: 1 EUR = 1.0605 USD (2023-03-02)
# [542/13043] Retrieved rate: 1 EUR = 1.0615 USD (2023-03-03)
# [543/13043] Retrieved rate: 1 EUR = 1.0619 USD (2023-02-28)
# [544/13043] Retrieved rate: 1 EUR = 1.0615 USD (2023-03-05)
# [545/13043] Retrieved rate: 1 EUR = 1.0615 USD (2023-03-04)
# [546/13043] Retrieved rate: 1 EUR = 1.0665 USD (2023-03-07)
# [547/13043] Retrieved rate: 1 EUR = 1.0545 USD (2023-03-08)
# [548/13043] Retrieved rate: 1 EUR = 1.0646 USD (2023-03-06)
# [549/13043] Retrieved rate: 1 EUR = 1.0554 USD (2023-03-09)
# [550/13043] Retrieved rate: 1 EUR = 1.0586 USD (2023-03-10)
# [551/13043] Retrieved rate: 1 EUR = 1.0706 USD (2023-03-13)
# [552/13043] Retrieved rate: 1 EUR = 1.0586 USD (2023-03-12)
# [553/13043] Retrieved rate: 1 EUR = 1.0586 USD (2023-03-11)
# [554/13043] Retrieved rate: 1 EUR = 1.0595 USD (2023-03-16)
# [555/13043] Retrieved rate: 1 EUR = 1.0623 USD (2023-03-17)
# [556/13043] Retrieved rate: 1 EUR = 1.0549 USD (2023-03-15)
# [557/13043] Retrieved rate: 1 EUR = 1.0737 USD (2023-03-14)
# [558/13043] Retrieved rate: 1 EUR = 1.0623 USD (2023-03-18)
# [559/13043] Retrieved rate: 1 EUR = 1.0623 USD (2023-03-19)
# [560/13043] Retrieved rate: 1 EUR = 1.0717 USD (2023-03-20)
# [561/13043] Retrieved rate: 1 EUR = 1.0776 USD (2023-03-21)
# [562/13043] Retrieved rate: 1 EUR = 1.0785 USD (2023-03-22)
# [563/13043] Retrieved rate: 1 EUR = 1.0745 USD (2023-03-25)
# [564/13043] Retrieved rate: 1 EUR = 1.0745 USD (2023-03-24)
# [565/13043] Retrieved rate: 1 EUR = 1.0879 USD (2023-03-23)
# [566/13043] Retrieved rate: 1 EUR = 1.0745 USD (2023-03-26)
# [567/13043] Retrieved rate: 1 EUR = 1.0773 USD (2023-03-27)
# [568/13043] Retrieved rate: 1 EUR = 1.0841 USD (2023-03-28)
# [569/13043] Retrieved rate: 1 EUR = 1.0847 USD (2023-03-29)
# [570/13043] Retrieved rate: 1 EUR = 1.0886 USD (2023-03-30)
# [571/13043] Retrieved rate: 1 EUR = 1.0875 USD (2023-04-02)
# [572/13043] Retrieved rate: 1 EUR = 1.0875 USD (2023-04-01)
# [573/13043] Retrieved rate: 1 EUR = 1.087 USD (2023-04-03)
# [574/13043] Retrieved rate: 1 EUR = 1.094 USD (2023-04-05)
# [575/13043] Retrieved rate: 1 EUR = 1.0901 USD (2023-04-04)
# [576/13043] Retrieved rate: 1 EUR = 1.0875 USD (2023-03-31)
# [577/13043] Retrieved rate: 1 EUR = 1.0915 USD (2023-04-06)
# [578/13043] Retrieved rate: 1 EUR = 1.0915 USD (2023-04-07)
# [579/13043] Retrieved rate: 1 EUR = 1.0915 USD (2023-04-09)
# [580/13043] Retrieved rate: 1 EUR = 1.0915 USD (2023-04-08)
# [581/13043] Retrieved rate: 1 EUR = 1.0915 USD (2023-04-10)
# [582/13043] Retrieved rate: 1 EUR = 1.1057 USD (2023-04-14)
# [583/13043] Retrieved rate: 1 EUR = 1.0905 USD (2023-04-11)
# [584/13043] Retrieved rate: 1 EUR = 1.1015 USD (2023-04-13)
# [585/13043] Retrieved rate: 1 EUR = 1.0922 USD (2023-04-12)
# [586/13043] Retrieved rate: 1 EUR = 1.1057 USD (2023-04-15)
# [587/13043] Retrieved rate: 1 EUR = 1.0981 USD (2023-04-17)
# [588/13043] Retrieved rate: 1 EUR = 1.1057 USD (2023-04-16)
# [589/13043] Retrieved rate: 1 EUR = 1.0972 USD (2023-04-18)
# [590/13043] Retrieved rate: 1 EUR = 1.0933 USD (2023-04-19)
# [591/13043] Retrieved rate: 1 EUR = 1.0978 USD (2023-04-21)
# [592/13043] Retrieved rate: 1 EUR = 1.0944 USD (2023-04-20)
# [593/13043] Retrieved rate: 1 EUR = 1.0978 USD (2023-04-22)
# [594/13043] Retrieved rate: 1 EUR = 1.1022 USD (2023-04-25)
# [595/13043] Retrieved rate: 1 EUR = 1.1002 USD (2023-04-24)
# [596/13043] Retrieved rate: 1 EUR = 1.0978 USD (2023-04-23)
# [597/13043] Retrieved rate: 1 EUR = 1.1039 USD (2023-04-26)
# [598/13043] Retrieved rate: 1 EUR = 1.0981 USD (2023-04-29)
# [599/13043] Retrieved rate: 1 EUR = 1.0981 USD (2023-04-28)
# [600/13043] Retrieved rate: 1 EUR = 1.1042 USD (2023-04-27)
# [601/13043] Retrieved rate: 1 EUR = 1.0981 USD (2023-04-30)
# [602/13043] Retrieved rate: 1 EUR = 1.0965 USD (2023-05-02)
# [603/13043] Retrieved rate: 1 EUR = 1.0981 USD (2023-05-01)
# [604/13043] Retrieved rate: 1 EUR = 1.1043 USD (2023-05-03)
# [605/13043] Retrieved rate: 1 EUR = 1.1074 USD (2023-05-04)
# [606/13043] Retrieved rate: 1 EUR = 1.1014 USD (2023-05-05)
# [607/13043] Retrieved rate: 1 EUR = 1.1014 USD (2023-05-07)
# [608/13043] Retrieved rate: 1 EUR = 1.1014 USD (2023-05-06)
# [609/13043] Retrieved rate: 1 EUR = 1.0959 USD (2023-05-09)
# [610/13043] Retrieved rate: 1 EUR = 1.1037 USD (2023-05-08)
# [611/13043] Retrieved rate: 1 EUR = 1.093 USD (2023-05-11)
# [612/13043] Retrieved rate: 1 EUR = 1.095 USD (2023-05-10)
# [613/13043] Retrieved rate: 1 EUR = 1.0892 USD (2023-05-12)
# [614/13043] Retrieved rate: 1 EUR = 1.0892 USD (2023-05-14)
# [615/13043] Retrieved rate: 1 EUR = 1.0881 USD (2023-05-16)
# [616/13043] Retrieved rate: 1 EUR = 1.0876 USD (2023-05-15)
# [617/13043] Retrieved rate: 1 EUR = 1.0892 USD (2023-05-13)
# [618/13043] Retrieved rate: 1 EUR = 1.0813 USD (2023-05-18)
# [619/13043] Retrieved rate: 1 EUR = 1.0808 USD (2023-05-19)
# [620/13043] Retrieved rate: 1 EUR = 1.0829 USD (2023-05-17)
# [621/13043] Retrieved rate: 1 EUR = 1.0808 USD (2023-05-20)
# [622/13043] Retrieved rate: 1 EUR = 1.0808 USD (2023-05-21)
# [623/13043] Retrieved rate: 1 EUR = 1.0779 USD (2023-05-23)
# [624/13043] Retrieved rate: 1 EUR = 1.0822 USD (2023-05-22)
# [625/13043] Retrieved rate: 1 EUR = 1.0785 USD (2023-05-24)
# [626/13043] Retrieved rate: 1 EUR = 1.0751 USD (2023-05-27)
# [627/13043] Retrieved rate: 1 EUR = 1.0751 USD (2023-05-28)
# [628/13043] Retrieved rate: 1 EUR = 1.0735 USD (2023-05-25)
# [629/13043] Retrieved rate: 1 EUR = 1.0751 USD (2023-05-26)
# [630/13043] Retrieved rate: 1 EUR = 1.0683 USD (2023-05-31)
# [631/13043] Retrieved rate: 1 EUR = 1.0697 USD (2023-06-01)
# [632/13043] Retrieved rate: 1 EUR = 1.0715 USD (2023-05-29)
# [633/13043] Retrieved rate: 1 EUR = 1.0763 USD (2023-06-02)
# [634/13043] Retrieved rate: 1 EUR = 1.0763 USD (2023-06-04)
# [635/13043] Retrieved rate: 1 EUR = 1.0744 USD (2023-05-30)
# [636/13043] Retrieved rate: 1 EUR = 1.0763 USD (2023-06-03)
# [637/13043] Retrieved rate: 1 EUR = 1.069 USD (2023-06-05)
# [638/13043] Retrieved rate: 1 EUR = 1.0683 USD (2023-06-06)
# [639/13043] Retrieved rate: 1 EUR = 1.0737 USD (2023-06-08)
# [640/13043] Retrieved rate: 1 EUR = 1.0717 USD (2023-06-07)
# [641/13043] Retrieved rate: 1 EUR = 1.078 USD (2023-06-09)
# [642/13043] Retrieved rate: 1 EUR = 1.0793 USD (2023-06-13)
# [643/13043] Retrieved rate: 1 EUR = 1.078 USD (2023-06-11)
# [644/13043] Retrieved rate: 1 EUR = 1.078 USD (2023-06-10)
# [645/13043] Retrieved rate: 1 EUR = 1.0765 USD (2023-06-12)
# [646/13043] Retrieved rate: 1 EUR = 1.0809 USD (2023-06-14)
# [647/13043] Retrieved rate: 1 EUR = 1.0819 USD (2023-06-15)
# [648/13043] Retrieved rate: 1 EUR = 1.0933 USD (2023-06-20)
# [649/13043] Retrieved rate: 1 EUR = 1.0966 USD (2023-06-18)
# [650/13043] Retrieved rate: 1 EUR = 1.0966 USD (2023-06-17)
# [651/13043] Retrieved rate: 1 EUR = 1.0966 USD (2023-06-16)
# [652/13043] Retrieved rate: 1 EUR = 1.0922 USD (2023-06-19)
# [653/13043] Retrieved rate: 1 EUR = 1.0923 USD (2023-06-21)
# [654/13043] Retrieved rate: 1 EUR = 1.0985 USD (2023-06-22)
# [655/13043] Retrieved rate: 1 EUR = 1.0884 USD (2023-06-24)
# [656/13043] Retrieved rate: 1 EUR = 1.0884 USD (2023-06-23)
# [657/13043] Retrieved rate: 1 EUR = 1.0884 USD (2023-06-25)
# [658/13043] Retrieved rate: 1 EUR = 1.0918 USD (2023-06-26)
# [659/13043] Retrieved rate: 1 EUR = 1.0951 USD (2023-06-27)
# [660/13043] Retrieved rate: 1 EUR = 1.0938 USD (2023-06-29)
# [661/13043] Retrieved rate: 1 EUR = 1.0938 USD (2023-06-28)
# [662/13043] Retrieved rate: 1 EUR = 1.0866 USD (2023-06-30)
# [663/13043] Retrieved rate: 1 EUR = 1.0866 USD (2023-07-01)
# [664/13043] Retrieved rate: 1 EUR = 1.0899 USD (2023-07-03)
# [665/13043] Retrieved rate: 1 EUR = 1.0866 USD (2023-07-02)
# [666/13043] Retrieved rate: 1 EUR = 1.0895 USD (2023-07-04)
# [667/13043] Retrieved rate: 1 EUR = 1.0899 USD (2023-07-06)
# [668/13043] Retrieved rate: 1 EUR = 1.0879 USD (2023-07-05)
# [669/13043] Retrieved rate: 1 EUR = 1.0888 USD (2023-07-07)
# [670/13043] Retrieved rate: 1 EUR = 1.0888 USD (2023-07-08)
# [671/13043] Retrieved rate: 1 EUR = 1.0888 USD (2023-07-09)
# [672/13043] Retrieved rate: 1 EUR = 1.0956 USD (2023-07-10)
# [673/13043] Retrieved rate: 1 EUR = 1.0989 USD (2023-07-11)
# [674/13043] Retrieved rate: 1 EUR = 1.1022 USD (2023-07-12)
# [675/13043] Retrieved rate: 1 EUR = 1.1221 USD (2023-07-14)
# [676/13043] Retrieved rate: 1 EUR = 1.1221 USD (2023-07-15)
# [677/13043] Retrieved rate: 1 EUR = 1.1182 USD (2023-07-13)
# [678/13043] Retrieved rate: 1 EUR = 1.1221 USD (2023-07-16)
# [679/13043] Retrieved rate: 1 EUR = 1.123 USD (2023-07-17)
# [680/13043] Retrieved rate: 1 EUR = 1.1255 USD (2023-07-18)
# [681/13043] Retrieved rate: 1 EUR = 1.1222 USD (2023-07-19)
# [682/13043] Retrieved rate: 1 EUR = 1.1197 USD (2023-07-20)
# [683/13043] Retrieved rate: 1 EUR = 1.1123 USD (2023-07-22)
# [684/13043] Retrieved rate: 1 EUR = 1.1123 USD (2023-07-21)
# [685/13043] Retrieved rate: 1 EUR = 1.1123 USD (2023-07-23)
# [686/13043] Retrieved rate: 1 EUR = 1.1096 USD (2023-07-24)
# [687/13043] Retrieved rate: 1 EUR = 1.1051 USD (2023-07-25)
# [688/13043] Retrieved rate: 1 EUR = 1.1125 USD (2023-07-27)
# [689/13043] Retrieved rate: 1 EUR = 1.1059 USD (2023-07-26)
# [690/13043] Retrieved rate: 1 EUR = 1.101 USD (2023-07-28)
# [691/13043] Retrieved rate: 1 EUR = 1.101 USD (2023-07-29)
# [692/13043] Retrieved rate: 1 EUR = 1.1023 USD (2023-07-31)
# [693/13043] Retrieved rate: 1 EUR = 1.101 USD (2023-07-30)
# [694/13043] Retrieved rate: 1 EUR = 1.097 USD (2023-08-01)
# [695/13043] Retrieved rate: 1 EUR = 1.0985 USD (2023-08-02)
# [696/13043] Retrieved rate: 1 EUR = 1.0946 USD (2023-08-04)
# [697/13043] Retrieved rate: 1 EUR = 1.0946 USD (2023-08-05)
# [698/13043] Retrieved rate: 1 EUR = 1.0932 USD (2023-08-03)
# [699/13043] Retrieved rate: 1 EUR = 1.0984 USD (2023-08-07)
# [700/13043] Retrieved rate: 1 EUR = 1.0946 USD (2023-08-06)
# [701/13043] Retrieved rate: 1 EUR = 1.0944 USD (2023-08-08)
# [702/13043] Retrieved rate: 1 EUR = 1.0968 USD (2023-08-09)
# [703/13043] Retrieved rate: 1 EUR = 1.1019 USD (2023-08-10)
# [704/13043] Retrieved rate: 1 EUR = 1.1004 USD (2023-08-11)
# [705/13043] Retrieved rate: 1 EUR = 1.1004 USD (2023-08-13)
# [706/13043] Retrieved rate: 1 EUR = 1.1004 USD (2023-08-12)
# [707/13043] Retrieved rate: 1 EUR = 1.093 USD (2023-08-14)
# [708/13043] Retrieved rate: 1 EUR = 1.0916 USD (2023-08-16)
# [709/13043] Retrieved rate: 1 EUR = 1.0926 USD (2023-08-15)
# [710/13043] Retrieved rate: 1 EUR = 1.09 USD (2023-08-17)
# [711/13043] Retrieved rate: 1 EUR = 1.0867 USD (2023-08-18)
# [712/13043] Retrieved rate: 1 EUR = 1.0867 USD (2023-08-19)
# [713/13043] Retrieved rate: 1 EUR = 1.0887 USD (2023-08-22)
# [714/13043] Retrieved rate: 1 EUR = 1.0867 USD (2023-08-20)
# [715/13043] Retrieved rate: 1 EUR = 1.0908 USD (2023-08-21)
# [716/13043] Retrieved rate: 1 EUR = 1.0805 USD (2023-08-23)
# [717/13043] Retrieved rate: 1 EUR = 1.084 USD (2023-08-24)
# [718/13043] Retrieved rate: 1 EUR = 1.0808 USD (2023-08-25)
# [719/13043] Retrieved rate: 1 EUR = 1.0808 USD (2023-08-26)
# [720/13043] Retrieved rate: 1 EUR = 1.0808 USD (2023-08-27)
# [721/13043] Retrieved rate: 1 EUR = 1.0886 USD (2023-08-30)
# [722/13043] Retrieved rate: 1 EUR = 1.0803 USD (2023-08-29)
# [723/13043] Retrieved rate: 1 EUR = 1.0868 USD (2023-08-31)
# [724/13043] Retrieved rate: 1 EUR = 1.0844 USD (2023-09-01)
# [725/13043] Retrieved rate: 1 EUR = 1.0844 USD (2023-09-02)
# [726/13043] Retrieved rate: 1 EUR = 1.0808 USD (2023-08-28)
# [727/13043] Retrieved rate: 1 EUR = 1.0844 USD (2023-09-03)
# [728/13043] Retrieved rate: 1 EUR = 1.0801 USD (2023-09-04)
# [729/13043] Retrieved rate: 1 EUR = 1.0731 USD (2023-09-05)
# [730/13043] Retrieved rate: 1 EUR = 1.071 USD (2023-09-07)
# [731/13043] Retrieved rate: 1 EUR = 1.0745 USD (2023-09-06)
# [732/13043] Retrieved rate: 1 EUR = 1.0704 USD (2023-09-08)
# [733/13043] Retrieved rate: 1 EUR = 1.0704 USD (2023-09-09)
# [734/13043] Retrieved rate: 1 EUR = 1.0724 USD (2023-09-11)
# [735/13043] Retrieved rate: 1 EUR = 1.0704 USD (2023-09-10)
# [736/13043] Retrieved rate: 1 EUR = 1.0713 USD (2023-09-12)
# [737/13043] Retrieved rate: 1 EUR = 1.073 USD (2023-09-14)
# [738/13043] Retrieved rate: 1 EUR = 1.0647 USD (2023-09-23)
# [739/13043] Retrieved rate: 1 EUR = 1.0635 USD (2023-09-21)
# [740/13043] Retrieved rate: 1 EUR = 1.0658 USD (2023-09-15)
# [741/13043] Retrieved rate: 1 EUR = 1.0647 USD (2023-09-22)
# [742/13043] Retrieved rate: 1 EUR = 1.0658 USD (2023-09-17)
# [743/13043] Retrieved rate: 1 EUR = 1.0713 USD (2023-09-19)
# [744/13043] Retrieved rate: 1 EUR = 1.0702 USD (2023-09-20)
# [745/13043] Retrieved rate: 1 EUR = 1.0663 USD (2023-09-18)
# [746/13043] Retrieved rate: 1 EUR = 1.0658 USD (2023-09-16)
# [747/13043] Retrieved rate: 1 EUR = 1.0733 USD (2023-09-13)
# [748/13043] Retrieved rate: 1 EUR = 1.0647 USD (2023-09-24)
# [749/13043] Retrieved rate: 1 EUR = 1.0605 USD (2023-09-26)
# [750/13043] Retrieved rate: 1 EUR = 1.0633 USD (2023-09-25)
# [751/13043] Retrieved rate: 1 EUR = 1.0536 USD (2023-09-27)
# [752/13043] Retrieved rate: 1 EUR = 1.0539 USD (2023-09-28)
# [753/13043] Retrieved rate: 1 EUR = 1.0594 USD (2023-09-29)
# [754/13043] Retrieved rate: 1 EUR = 1.0594 USD (2023-09-30)
# [755/13043] Retrieved rate: 1 EUR = 1.0594 USD (2023-10-01)
# [756/13043] Retrieved rate: 1 EUR = 1.053 USD (2023-10-02)
# [757/13043] Retrieved rate: 1 EUR = 1.0563 USD (2023-10-07)
# [758/13043] Retrieved rate: 1 EUR = 1.0526 USD (2023-10-05)
# [759/13043] Retrieved rate: 1 EUR = 1.0531 USD (2023-10-09)
# [760/13043] Retrieved rate: 1 EUR = 1.0582 USD (2023-10-10)
# [761/13043] Retrieved rate: 1 EUR = 1.0563 USD (2023-10-08)
# [762/13043] Retrieved rate: 1 EUR = 1.0563 USD (2023-10-06)
# [763/13043] Retrieved rate: 1 EUR = 1.0524 USD (2023-10-13)
# [764/13043] Retrieved rate: 1 EUR = 1.0497 USD (2023-10-04)
# [765/13043] Retrieved rate: 1 EUR = 1.0524 USD (2023-10-14)
# [766/13043] Retrieved rate: 1 EUR = 1.0469 USD (2023-10-03)
# [767/13043] Retrieved rate: 1 EUR = 1.0604 USD (2023-10-11)
# [768/13043] Retrieved rate: 1 EUR = 1.0619 USD (2023-10-12)
# [769/13043] Retrieved rate: 1 EUR = 1.0524 USD (2023-10-15)
# [770/13043] Retrieved rate: 1 EUR = 1.0538 USD (2023-10-16)
# [771/13043] Retrieved rate: 1 EUR = 1.0565 USD (2023-10-18)
# [772/13043] Retrieved rate: 1 EUR = 1.0569 USD (2023-10-17)
# [773/13043] Retrieved rate: 1 EUR = 1.0591 USD (2023-10-20)
# [774/13043] Retrieved rate: 1 EUR = 1.0576 USD (2023-10-25)
# [775/13043] Retrieved rate: 1 EUR = 1.0661 USD (2023-11-02)
# [776/13043] Retrieved rate: 1 EUR = 1.0702 USD (2023-11-03)
# [777/13043] Retrieved rate: 1 EUR = 1.0597 USD (2023-10-23)
# [778/13043] Retrieved rate: 1 EUR = 1.054 USD (2023-10-26)
# [779/13043] Retrieved rate: 1 EUR = 1.0591 USD (2023-10-22)
# [780/13043] Retrieved rate: 1 EUR = 1.0541 USD (2023-10-28)
# [781/13043] Retrieved rate: 1 EUR = 1.0619 USD (2023-10-31)
# [782/13043] Retrieved rate: 1 EUR = 1.0541 USD (2023-10-27)
# [783/13043] Retrieved rate: 1 EUR = 1.0605 USD (2023-10-30)
# [784/13043] Retrieved rate: 1 EUR = 1.0558 USD (2023-10-19)
# [785/13043] Retrieved rate: 1 EUR = 1.0537 USD (2023-11-01)
# [786/13043] Retrieved rate: 1 EUR = 1.0541 USD (2023-10-29)
# [787/13043] Retrieved rate: 1 EUR = 1.0632 USD (2023-10-24)
# [788/13043] Retrieved rate: 1 EUR = 1.0591 USD (2023-10-21)
# [789/13043] Retrieved rate: 1 EUR = 1.0702 USD (2023-11-04)
# [790/13043] Retrieved rate: 1 EUR = 1.0686 USD (2023-11-07)
# [791/13043] Retrieved rate: 1 EUR = 1.0702 USD (2023-11-05)
# [792/13043] Retrieved rate: 1 EUR = 1.0741 USD (2023-11-06)
# [793/13043] Retrieved rate: 1 EUR = 1.0671 USD (2023-11-08)
# [794/13043] Retrieved rate: 1 EUR = 1.0691 USD (2023-11-09)
# [795/13043] Retrieved rate: 1 EUR = 1.0724 USD (2023-11-14)
# [796/13043] Retrieved rate: 1 EUR = 1.0872 USD (2023-11-17)
# [797/13043] Retrieved rate: 1 EUR = 1.0872 USD (2023-11-18)
# [798/13043] Retrieved rate: 1 EUR = 1.067 USD (2023-11-13)
# [799/13043] Retrieved rate: 1 EUR = 1.0849 USD (2023-11-16)
# ...
# [12796/13043] Retrieved rate: 1 CHF = 1.1143 USD (2023-06-21)
# [12797/13043] Retrieved rate: 1 CHF = 1.1181 USD (2023-06-22)
# [12798/13043] Retrieved rate: 1 CHF = 1.1224 USD (2023-06-18)
# [12799/13043] Retrieved rate: 1 CHF = 1.1177 USD (2023-06-19)
# [12800/13043] Retrieved rate: 1 CHF = 1.1147 USD (2023-06-20)
# [12801/13043] Retrieved rate: 1 CHF = 1.1137 USD (2023-06-23)
# [12802/13043] Retrieved rate: 1 CHF = 1.1084 USD (2023-06-15)
# [12803/13043] Retrieved rate: 1 CHF = 1.1137 USD (2023-06-25)
# [12804/13043] Retrieved rate: 1 CHF = 1.1187 USD (2023-06-27)
# [12805/13043] Retrieved rate: 1 CHF = 1.1137 USD (2023-06-24)
# [12806/13043] Retrieved rate: 1 CHF = 1.1136 USD (2023-06-28)
# [12807/13043] Retrieved rate: 1 CHF = 1.1181 USD (2023-06-29)
# [12808/13043] Retrieved rate: 1 CHF = 1.1213 USD (2023-06-26)
# [12809/13043] Retrieved rate: 1 CHF = 1.1101 USD (2023-06-30)
# [12810/13043] Retrieved rate: 1 CHF = 1.1101 USD (2023-07-01)
# [12811/13043] Retrieved rate: 1 CHF = 1.1163 USD (2023-07-08)
# [12812/13043] Retrieved rate: 1 CHF = 1.1163 USD (2023-07-09)
# [12813/13043] Retrieved rate: 1 CHF = 1.117 USD (2023-07-06)
# [12814/13043] Retrieved rate: 1 CHF = 1.1163 USD (2023-07-07)
# [12815/13043] Retrieved rate: 1 CHF = 1.1161 USD (2023-07-04)
# [12816/13043] Retrieved rate: 1 CHF = 1.1101 USD (2023-07-02)
# [12817/13043] Retrieved rate: 1 CHF = 1.1121 USD (2023-07-03)
# [12818/13043] Retrieved rate: 1 CHF = 1.1121 USD (2023-07-05)
# [12819/13043] Retrieved rate: 1 CHF = 1.1595 USD (2023-07-13)
# [12820/13043] Retrieved rate: 1 CHF = 1.1233 USD (2023-07-10)
# [12821/13043] Retrieved rate: 1 CHF = 1.1629 USD (2023-07-14)
# [12822/13043] Retrieved rate: 1 CHF = 1.1383 USD (2023-07-12)
# [12823/13043] Retrieved rate: 1 CHF = 1.1629 USD (2023-07-16)
# [12824/13043] Retrieved rate: 1 CHF = 1.1337 USD (2023-07-11)
# [12825/13043] Retrieved rate: 1 CHF = 1.1629 USD (2023-07-15)
# [12826/13043] Retrieved rate: 1 CHF = 1.1635 USD (2023-07-17)
# [12827/13043] Retrieved rate: 1 CHF = 1.1667 USD (2023-07-18)
# [12828/13043] Retrieved rate: 1 CHF = 1.155 USD (2023-07-23)
# [12829/13043] Retrieved rate: 1 CHF = 1.1656 USD (2023-07-19)
# [12830/13043] Retrieved rate: 1 CHF = 1.155 USD (2023-07-21)
# [12831/13043] Retrieved rate: 1 CHF = 1.1659 USD (2023-07-27)
# [12832/13043] Retrieved rate: 1 CHF = 1.1514 USD (2023-07-25)
# [12833/13043] Retrieved rate: 1 CHF = 1.1581 USD (2023-07-26)
# [12834/13043] Retrieved rate: 1 CHF = 1.155 USD (2023-07-22)
# [12835/13043] Retrieved rate: 1 CHF = 1.1621 USD (2023-07-20)
# [12836/13043] Retrieved rate: 1 CHF = 1.1564 USD (2023-07-24)
# [12837/13043] Retrieved rate: 1 CHF = 1.1393 USD (2023-08-02)
# [12838/13043] Retrieved rate: 1 CHF = 1.1415 USD (2023-08-01)
# [12839/13043] Retrieved rate: 1 CHF = 1.1524 USD (2023-07-29)
# [12840/13043] Retrieved rate: 1 CHF = 1.1524 USD (2023-07-30)
# [12841/13043] Retrieved rate: 1 CHF = 1.146 USD (2023-07-31)
# [12842/13043] Retrieved rate: 1 CHF = 1.1524 USD (2023-07-28)
# [12843/13043] Retrieved rate: 1 CHF = 1.1412 USD (2023-08-03)
# [12844/13043] Retrieved rate: 1 CHF = 1.1412 USD (2023-08-07)
# [12845/13043] Retrieved rate: 1 CHF = 1.1404 USD (2023-08-06)
# [12846/13043] Retrieved rate: 1 CHF = 1.1393 USD (2023-08-09)
# [12847/13043] Retrieved rate: 1 CHF = 1.1404 USD (2023-08-04)
# [12848/13043] Retrieved rate: 1 CHF = 1.1404 USD (2023-08-05)
# [12849/13043] Retrieved rate: 1 CHF = 1.1442 USD (2023-08-12)
# [12850/13043] Retrieved rate: 1 CHF = 1.14 USD (2023-08-08)
# [12851/13043] Retrieved rate: 1 CHF = 1.1354 USD (2023-08-18)
# [12852/13043] Retrieved rate: 1 CHF = 1.1457 USD (2023-08-10)
# [12853/13043] Retrieved rate: 1 CHF = 1.1442 USD (2023-08-13)
# [12854/13043] Retrieved rate: 1 CHF = 1.1442 USD (2023-08-11)
# [12855/13043] Retrieved rate: 1 CHF = 1.1398 USD (2023-08-15)
# [12856/13043] Retrieved rate: 1 CHF = 1.1354 USD (2023-08-19)
# [12857/13043] Retrieved rate: 1 CHF = 1.1408 USD (2023-08-17)
# [12858/13043] Retrieved rate: 1 CHF = 1.1376 USD (2023-08-14)
# [12859/13043] Retrieved rate: 1 CHF = 1.1365 USD (2023-08-16)
# [12860/13043] Retrieved rate: 1 CHF = 1.1354 USD (2023-08-20)
# [12861/13043] Retrieved rate: 1 CHF = 1.1382 USD (2023-08-22)
# [12862/13043] Retrieved rate: 1 CHF = 1.1377 USD (2023-08-21)
# [12863/13043] Retrieved rate: 1 CHF = 1.1345 USD (2023-08-23)
# [12864/13043] Retrieved rate: 1 CHF = 1.1337 USD (2023-08-24)
# [12865/13043] Retrieved rate: 1 CHF = 1.1301 USD (2023-08-27)
# [12866/13043] Retrieved rate: 1 CHF = 1.1303 USD (2023-08-29)
# [12867/13043] Retrieved rate: 1 CHF = 1.1301 USD (2023-08-25)
# [12868/13043] Retrieved rate: 1 CHF = 1.1301 USD (2023-08-26)
# [12869/13043] Retrieved rate: 1 CHF = 1.1378 USD (2023-08-30)
# [12870/13043] Retrieved rate: 1 CHF = 1.1307 USD (2023-08-28)
# [12871/13043] Retrieved rate: 1 CHF = 1.1327 USD (2023-09-01)
# [12872/13043] Retrieved rate: 1 CHF = 1.134 USD (2023-08-31)
# [12873/13043] Retrieved rate: 1 CHF = 1.1312 USD (2023-09-04)
# [12874/13043] Retrieved rate: 1 CHF = 1.1239 USD (2023-09-05)
# [12875/13043] Retrieved rate: 1 CHF = 1.1327 USD (2023-09-02)
# [12876/13043] Retrieved rate: 1 CHF = 1.1327 USD (2023-09-03)
# [12877/13043] Retrieved rate: 1 CHF = 1.1206 USD (2023-09-07)
# [12878/13043] Retrieved rate: 1 CHF = 1.1238 USD (2023-09-06)
# [12879/13043] Retrieved rate: 1 CHF = 1.1217 USD (2023-09-09)
# [12880/13043] Retrieved rate: 1 CHF = 1.1217 USD (2023-09-08)
# [12881/13043] Retrieved rate: 1 CHF = 1.1193 USD (2023-09-13)
# [12882/13043] Retrieved rate: 1 CHF = 1.1205 USD (2023-09-12)
# [12883/13043] Retrieved rate: 1 CHF = 1.1218 USD (2023-09-11)
# [12884/13043] Retrieved rate: 1 CHF = 1.1217 USD (2023-09-10)
# [12885/13043] Retrieved rate: 1 CHF = 1.1191 USD (2023-09-14)
# [12886/13043] Retrieved rate: 1 CHF = 1.1156 USD (2023-09-16)
# [12887/13043] Retrieved rate: 1 CHF = 1.1156 USD (2023-09-15)
# [12888/13043] Retrieved rate: 1 CHF = 1.1165 USD (2023-09-19)
# [12889/13043] Retrieved rate: 1 CHF = 1.1149 USD (2023-09-18)
# [12890/13043] Retrieved rate: 1 CHF = 1.1033 USD (2023-09-23)
# [12891/13043] Retrieved rate: 1 CHF = 1.1156 USD (2023-09-17)
# [12892/13043] Retrieved rate: 1 CHF = 1.1046 USD (2023-09-21)
# [12893/13043] Retrieved rate: 1 CHF = 1.1147 USD (2023-09-20)
# [12894/13043] Retrieved rate: 1 CHF = 1.1033 USD (2023-09-22)
# [12895/13043] Retrieved rate: 1 CHF = 1.0957 USD (2023-09-29)
# [12896/13043] Retrieved rate: 1 CHF = 1.1033 USD (2023-09-24)
# [12897/13043] Retrieved rate: 1 CHF = 1.0989 USD (2023-09-25)
# [12898/13043] Retrieved rate: 1 CHF = 1.089 USD (2023-09-28)
# [12899/13043] Retrieved rate: 1 CHF = 1.0961 USD (2023-09-26)
# [12900/13043] Retrieved rate: 1 CHF = 1.0884 USD (2023-09-27)
# [12901/13043] Retrieved rate: 1 CHF = 1.0957 USD (2023-10-01)
# [12902/13043] Retrieved rate: 1 CHF = 1.0957 USD (2023-09-30)
# [12903/13043] Retrieved rate: 1 CHF = 1.093 USD (2023-10-02)
# [12904/13043] Retrieved rate: 1 CHF = 1.0837 USD (2023-10-03)
# [12905/13043] Retrieved rate: 1 CHF = 1.0936 USD (2023-10-05)
# [12906/13043] Retrieved rate: 1 CHF = 1.097 USD (2023-10-06)
# [12907/13043] Retrieved rate: 1 CHF = 1.1036 USD (2023-10-10)
# [12908/13043] Retrieved rate: 1 CHF = 1.0896 USD (2023-10-04)
# [12909/13043] Retrieved rate: 1 CHF = 1.097 USD (2023-10-07)
# [12910/13043] Retrieved rate: 1 CHF = 1.0992 USD (2023-10-09)
# [12911/13043] Retrieved rate: 1 CHF = 1.1074 USD (2023-10-11)
# [12912/13043] Retrieved rate: 1 CHF = 1.097 USD (2023-10-08)
# [12913/13043] Retrieved rate: 1 CHF = 1.1101 USD (2023-10-12)
# [12914/13043] Retrieved rate: 1 CHF = 1.1025 USD (2023-10-13)
# [12915/13043] Retrieved rate: 1 CHF = 1.1087 USD (2023-10-16)
# [12916/13043] Retrieved rate: 1 CHF = 1.1025 USD (2023-10-15)
# [12917/13043] Retrieved rate: 1 CHF = 1.1025 USD (2023-10-14)
# [12918/13043] Retrieved rate: 1 CHF = 1.1217 USD (2023-10-20)
# [12919/13043] Retrieved rate: 1 CHF = 1.1105 USD (2023-10-17)
# [12920/13043] Retrieved rate: 1 CHF = 1.1149 USD (2023-10-19)
# [12921/13043] Retrieved rate: 1 CHF = 1.1217 USD (2023-10-22)
# [12922/13043] Retrieved rate: 1 CHF = 1.113 USD (2023-10-18)
# [12923/13043] Retrieved rate: 1 CHF = 1.1201 USD (2023-10-23)
# [12924/13043] Retrieved rate: 1 CHF = 1.1217 USD (2023-10-21)
# [12925/13043] Retrieved rate: 1 CHF = 1.1163 USD (2023-10-25)
# [12926/13043] Retrieved rate: 1 CHF = 1.1135 USD (2023-10-26)
# [12927/13043] Retrieved rate: 1 CHF = 1.1093 USD (2023-10-28)
# [12928/13043] Retrieved rate: 1 CHF = 1.119 USD (2023-10-24)
# [12929/13043] Retrieved rate: 1 CHF = 1.1088 USD (2023-10-30)
# [12930/13043] Retrieved rate: 1 CHF = 1.1093 USD (2023-10-27)
# [12931/13043] Retrieved rate: 1 CHF = 1.1093 USD (2023-10-29)
# [12932/13043] Retrieved rate: 1 CHF = 1.1119 USD (2023-11-03)
# [12933/13043] Retrieved rate: 1 CHF = 1.1119 USD (2023-11-04)
# [12934/13043] Retrieved rate: 1 CHF = 1.1053 USD (2023-10-31)
# [12935/13043] Retrieved rate: 1 CHF = 1.108 USD (2023-11-02)
# [12936/13043] Retrieved rate: 1 CHF = 1.1008 USD (2023-11-01)
# [12937/13043] Retrieved rate: 1 CHF = 1.1119 USD (2023-11-05)
# [12938/13043] Retrieved rate: 1 CHF = 1.1135 USD (2023-11-06)
# [12939/13043] Retrieved rate: 1 CHF = 1.1094 USD (2023-11-09)
# [12940/13043] Retrieved rate: 1 CHF = 1.1274 USD (2023-11-15)
# [12941/13043] Retrieved rate: 1 CHF = 1.105 USD (2023-11-13)
# [12942/13043] Retrieved rate: 1 CHF = 1.1274 USD (2023-11-19)
# [12943/13043] Retrieved rate: 1 CHF = 1.1274 USD (2023-11-17)
# [12944/13043] Retrieved rate: 1 CHF = 1.1087 USD (2023-11-12)
# [12945/13043] Retrieved rate: 1 CHF = 1.1117 USD (2023-11-08)
# [12946/13043] Retrieved rate: 1 CHF = 1.1101 USD (2023-11-07)
# [12947/13043] Retrieved rate: 1 CHF = 1.1092 USD (2023-11-14)
# [12948/13043] Retrieved rate: 1 CHF = 1.1307 USD (2023-11-20)
# [12949/13043] Retrieved rate: 1 CHF = 1.1087 USD (2023-11-10)
# [12950/13043] Retrieved rate: 1 CHF = 1.1241 USD (2023-11-16)
# [12951/13043] Retrieved rate: 1 CHF = 1.1087 USD (2023-11-11)
# [12952/13043] Retrieved rate: 1 CHF = 1.1274 USD (2023-11-18)
# [12953/13043] Retrieved rate: 1 CHF = 1.1325 USD (2023-11-21)
# [12954/13043] Retrieved rate: 1 CHF = 1.1302 USD (2023-11-23)
# [12955/13043] Retrieved rate: 1 CHF = 1.1324 USD (2023-11-24)
# [12956/13043] Retrieved rate: 1 CHF = 1.1318 USD (2023-11-22)
# [12957/13043] Retrieved rate: 1 CHF = 1.1324 USD (2023-11-26)
# [12958/13043] Retrieved rate: 1 CHF = 1.1324 USD (2023-11-25)
# [12959/13043] Retrieved rate: 1 CHF = 1.136 USD (2023-11-27)
# [12960/13043] Retrieved rate: 1 CHF = 1.1432 USD (2023-11-30)
# [12961/13043] Retrieved rate: 1 CHF = 1.1409 USD (2023-11-29)
# [12962/13043] Retrieved rate: 1 CHF = 1.1411 USD (2023-12-01)
# [12963/13043] Retrieved rate: 1 CHF = 1.1352 USD (2023-11-28)
# [12964/13043] Retrieved rate: 1 CHF = 1.1411 USD (2023-12-02)
# [12965/13043] Retrieved rate: 1 CHF = 1.1403 USD (2023-12-07)
# [12966/13043] Retrieved rate: 1 CHF = 1.1469 USD (2023-12-04)
# [12967/13043] Retrieved rate: 1 CHF = 1.1419 USD (2023-12-08)
# [12968/13043] Retrieved rate: 1 CHF = 1.1431 USD (2023-12-06)
# [12969/13043] Retrieved rate: 1 CHF = 1.1411 USD (2023-12-03)
# [12970/13043] Retrieved rate: 1 CHF = 1.1419 USD (2023-12-10)
# [12971/13043] Retrieved rate: 1 CHF = 1.1439 USD (2023-12-05)
# [12972/13043] Retrieved rate: 1 CHF = 1.1419 USD (2023-12-09)
# [12973/13043] Retrieved rate: 1 CHF = 1.1349 USD (2023-12-11)
# [12974/13043] Retrieved rate: 1 CHF = 1.1441 USD (2023-12-12)
# [12975/13043] Retrieved rate: 1 CHF = 1.1412 USD (2023-12-13)
# [12976/13043] Retrieved rate: 1 CHF = 1.1506 USD (2023-12-14)
# [12977/13043] Retrieved rate: 1 CHF = 1.1569 USD (2023-12-20)
# [12978/13043] Retrieved rate: 1 CHF = 1.1517 USD (2023-12-18)
# [12979/13043] Retrieved rate: 1 CHF = 1.1576 USD (2023-12-19)
# [12980/13043] Retrieved rate: 1 CHF = 1.1537 USD (2023-12-15)
# [12981/13043] Retrieved rate: 1 CHF = 1.1537 USD (2023-12-16)
# [12982/13043] Retrieved rate: 1 CHF = 1.1705 USD (2023-12-26)
# [12983/13043] Retrieved rate: 1 CHF = 1.1537 USD (2023-12-17)
# [12984/13043] Retrieved rate: 1 CHF = 1.1705 USD (2023-12-22)
# [12985/13043] Retrieved rate: 1 CHF = 1.1724 USD (2023-12-27)
# [12986/13043] Retrieved rate: 1 CHF = 1.1933 USD (2023-12-30)
# [12987/13043] Retrieved rate: 1 CHF = 1.1705 USD (2023-12-23)
# [12988/13043] Retrieved rate: 1 CHF = 1.1933 USD (2023-12-29)
# [12989/13043] Retrieved rate: 1 CHF = 1.1948 USD (2023-12-28)
# [12990/13043] Retrieved rate: 1 CHF = 1.1705 USD (2023-12-24)
# [12991/13043] Retrieved rate: 1 CHF = 1.1705 USD (2023-12-25)
# [12992/13043] Retrieved rate: 1 CHF = 1.1644 USD (2023-12-21)
# [12993/13043] Retrieved rate: 1 CHF = 1.1933 USD (2023-12-31)
# [12994/13043] Retrieved rate: 1 CHF = 1.1774 USD (2024-01-02)
# [12995/13043] Retrieved rate: 1 CHF = 1.176 USD (2024-01-08)
# [12996/13043] Retrieved rate: 1 CHF = 1.1718 USD (2024-01-05)
# [12997/13043] Retrieved rate: 1 CHF = 1.1933 USD (2024-01-01)
# [12998/13043] Retrieved rate: 1 CHF = 1.1718 USD (2024-01-06)
# [12999/13043] Retrieved rate: 1 CHF = 1.1713 USD (2024-01-03)
# [13000/13043] Retrieved rate: 1 CHF = 1.1761 USD (2024-01-04)
# [13001/13043] Retrieved rate: 1 CHF = 1.1718 USD (2024-01-07)
# [13002/13043] Retrieved rate: 1 CHF = 1.1725 USD (2024-01-10)
# [13003/13043] Retrieved rate: 1 CHF = 1.1766 USD (2024-01-11)
# [13004/13043] Retrieved rate: 1 CHF = 1.1747 USD (2024-01-09)
# [13005/13043] Retrieved rate: 1 CHF = 1.1703 USD (2024-01-12)
# [13006/13043] Retrieved rate: 1 CHF = 1.1703 USD (2024-01-14)
# [13007/13043] Retrieved rate: 1 CHF = 1.1703 USD (2024-01-13)
# [13008/13043] Retrieved rate: 1 CHF = 1.1705 USD (2024-01-15)
# [13009/13043] Retrieved rate: 1 CHF = 1.1564 USD (2024-01-17)
# [13010/13043] Retrieved rate: 1 CHF = 1.153 USD (2024-01-18)
# [13011/13043] Retrieved rate: 1 CHF = 1.1625 USD (2024-01-16)
# [13012/13043] Retrieved rate: 1 CHF = 1.151 USD (2024-01-19)
# [13013/13043] Retrieved rate: 1 CHF = 1.151 USD (2024-01-20)
# [13014/13043] Retrieved rate: 1 CHF = 1.1514 USD (2024-01-22)
# [13015/13043] Retrieved rate: 1 CHF = 1.151 USD (2024-01-23)
# [13016/13043] Retrieved rate: 1 CHF = 1.1583 USD (2024-01-24)
# [13017/13043] Retrieved rate: 1 CHF = 1.151 USD (2024-01-21)
# [13018/13043] Retrieved rate: 1 CHF = 1.1589 USD (2024-01-29)
# [13019/13043] Retrieved rate: 1 CHF = 1.157 USD (2024-01-28)
# [13020/13043] Retrieved rate: 1 CHF = 1.1564 USD (2024-01-25)
# [13021/13043] Retrieved rate: 1 CHF = 1.157 USD (2024-01-26)
# [13022/13043] Retrieved rate: 1 CHF = 1.157 USD (2024-01-27)
# [13023/13043] Retrieved rate: 1 CHF = 1.1593 USD (2024-01-31)
# [13024/13043] Retrieved rate: 1 CHF = 1.1581 USD (2024-01-30)
# [13025/13043] Retrieved rate: 1 CHF = 1.1683 USD (2024-02-02)
# [13026/13043] Retrieved rate: 1 CHF = 1.1497 USD (2024-02-05)
# [13027/13043] Retrieved rate: 1 CHF = 1.1683 USD (2024-02-04)
# [13028/13043] Retrieved rate: 1 CHF = 1.1583 USD (2024-02-01)
# [13029/13043] Retrieved rate: 1 CHF = 1.1683 USD (2024-02-03)
# [13030/13043] Retrieved rate: 1 CHF = 1.147 USD (2024-02-06)
# [13031/13043] Retrieved rate: 1 CHF = 1.1384 USD (2024-02-13)
# [13032/13043] Retrieved rate: 1 CHF = 1.1421 USD (2024-02-11)
# [13033/13043] Retrieved rate: 1 CHF = 1.1345 USD (2024-02-17)
# [13034/13043] Retrieved rate: 1 CHF = 1.1472 USD (2024-02-07)
# [13035/13043] Retrieved rate: 1 CHF = 1.1434 USD (2024-02-08)
# [13036/13043] Retrieved rate: 1 CHF = 1.1421 USD (2024-02-09)
# [13037/13043] Retrieved rate: 1 CHF = 1.1345 USD (2024-02-18)
# [13038/13043] Retrieved rate: 1 CHF = 1.1353 USD (2024-02-19)
# [13039/13043] Retrieved rate: 1 CHF = 1.1421 USD (2024-02-10)
# [13040/13043] Retrieved rate: 1 CHF = 1.1285 USD (2024-02-14)
# [13041/13043] Retrieved rate: 1 CHF = 1.1345 USD (2024-02-16)
# [13042/13043] Retrieved rate: 1 CHF = 1.1424 USD (2024-02-12)
# [13043/13043] Retrieved rate: 1 CHF = 1.1327 USD (2024-02-15)
# WARNING: Failed to resolve 923 FX pairs. Those rows will remain unconverted.
#  - 2021-11-23 CLP: unsupported_or_missing_on_source
#  - 2021-11-24 CLP: unsupported_or_missing_on_source
#  - 2021-11-28 CLP: unsupported_or_missing_on_source
#  - 2021-11-27 CLP: unsupported_or_missing_on_source
#  - 2021-11-26 CLP: unsupported_or_missing_on_source
# Applying FX rates to dataframe...
# FX_TO_USD column created.
# WARNING: 923 rows have no FX rate and were not converted.
# Created 15 *_USD columns.
# Original monetary columns converted to USD values where FX was available.
# Currency normalization complete for successfully converted rows.

# %%
# Drop rows where FX conversion was not available.
if "FX_TO_USD" not in df.columns:
    raise KeyError("FX_TO_USD column not found. Run the FX conversion cell first.")

rows_before = len(df)
df = df[df["FX_TO_USD"].notna()].reset_index(drop=True)
rows_after = len(df)
removed_rows = rows_before - rows_after

print(f"Removed {removed_rows:,} unconverted rows.")
print(f"Remaining rows: {rows_after:,}")
# Out:
# Removed 923 unconverted rows.
# Remaining rows: 131,836

# %%
output_path = "mmm_to_usd.csv"
df.to_csv(output_path, index=False)
print(f"Saved dataframe to: {output_path}")
# Out:
# Saved dataframe to: mmm_to_usd.csv

# %%
ad_spend_cols = google_spend_cols + meta_spend_cols + ["TIKTOK_SPEND"]

org_ad_spend = (
    df.groupby("ORGANISATION_ID", as_index=False)[ad_spend_cols]
      .sum()
)

org_ad_spend["TOTAL_AD_SPEND"] = org_ad_spend[ad_spend_cols].sum(axis=1)

# Ensure ranking is highest spend to lowest spend.
org_ad_spend = org_ad_spend.sort_values("TOTAL_AD_SPEND", ascending=False).reset_index(drop=True)

currency_cols = ad_spend_cols + ["TOTAL_AD_SPEND"]

# Display-only copy formatted as dollars (no jinja2/.style dependency).
org_ad_spend_display = org_ad_spend.copy()
for col in currency_cols:
    org_ad_spend_display[col] = org_ad_spend_display[col].map(lambda x: f"${x:,.2f}")

org_ad_spend_display
# Out:
#                      ORGANISATION_ID GOOGLE_PAID_SEARCH_SPEND  \
# 0   5488b06e575cc0e13be2cd67325ffa33           $18,043,196.54
# 1   784d6aa3cda59f59f2400332b2420a49              $243,066.82
# 2   ba773ebd7ec0a08f1d042187d086ccb4              $591,098.19
# 3   7569a6a9c156a0f9398fa6cfd51df5bb            $2,954,450.17
# 4   429c8d00704a9ef6307b49f22d5dfade              $352,665.66
# ..                               ...                      ...
# 88  c91b1af7a86a8531877e63273d95c0fb               $11,335.28
# 89  3f4463f3b51fc2056b97766e2373747d               $25,855.49
# 90  6dded930ff616b1ec8a3094208238208                    $0.00
# 91  eb830407a05a61a3bef88f720abf9500                  $495.66
# 92  f1504c791a2b4aa6fac0861259e0e212                $1,263.49
#
#    GOOGLE_SHOPPING_SPEND GOOGLE_PMAX_SPEND GOOGLE_DISPLAY_SPEND  \
# 0          $3,319,455.41    $74,198,869.71        $6,603,876.49
# 1          $1,746,040.86     $3,307,710.80          $256,541.39
# 2         $15,544,525.11     $2,304,243.53              $654.99
# 3            $384,417.00     $2,525,722.82              $452.26
# 4         $11,679,610.67     $2,256,458.10              $882.45
# ..                   ...               ...                  ...
# 88             $2,663.36         $4,437.34              $820.90
# 89                 $0.00        $16,820.18                $0.00
# 90                 $0.00             $0.00                $0.00
# 91             $1,316.49        $21,619.00                $0.00
# 92             $6,941.83         $3,320.59                $0.00
#
#    GOOGLE_VIDEO_SPEND META_FACEBOOK_SPEND META_INSTAGRAM_SPEND  \
# 0      $16,221,684.81     $624,047,463.86      $226,010,521.15
# 1          $25,117.75      $20,541,590.88        $7,773,282.20
# 2             $221.32         $698,598.69           $31,595.17
# 3         $620,105.22       $9,514,551.29          $485,748.15
# 4               $0.00         $241,747.60           $44,449.98
# ..                ...                 ...                  ...
# 88              $0.00          $35,999.22                $0.00
# 89              $0.00               $0.00                $0.00
# 90              $0.00          $17,077.53            $6,819.81
# 91              $0.00               $0.00                $0.00
# 92              $0.00               $0.00                $0.00
#
#    META_OTHER_SPEND   TIKTOK_SPEND   TOTAL_AD_SPEND
# 0       $484,803.23          $0.00  $968,929,871.20
# 1        $60,289.37          $0.00   $33,953,640.07
# 2         $1,562.08          $0.00   $19,172,499.09
# 3         $2,369.61  $1,129,804.99   $17,617,621.52
# 4         $1,571.92          $0.00   $14,577,386.37
# ..              ...            ...              ...
# 88            $0.00          $0.00       $55,256.10
# 89            $0.00          $0.00       $42,675.67
# 90           $30.09          $0.00       $23,927.44
# 91            $0.00          $0.00       $23,431.15
# 92            $0.00          $0.00       $11,525.90
#
# [93 rows x 11 columns]

# %%
# Create a single target variable for modeling.
required_cols = ["ALL_PURCHASES_ORIGINAL_PRICE", "ALL_PURCHASES_GROSS_DISCOUNT"]
missing_cols = [c for c in required_cols if c not in df.columns]

if missing_cols:
    raise KeyError(f"Missing required columns for revenue target: {missing_cols}")

df["revenue"] = df["ALL_PURCHASES_ORIGINAL_PRICE"] - df["ALL_PURCHASES_GROSS_DISCOUNT"]

# This is your modeling target (y).
y = df["revenue"]

print("Created target variable: revenue")
print(f"Rows: {len(df):,} | Nulls in revenue: {df['revenue'].isna().sum():,}")
df[["ALL_PURCHASES_ORIGINAL_PRICE", "ALL_PURCHASES_GROSS_DISCOUNT", "revenue"]].head()
# Out:
# Created target variable: revenue
# Rows: 132,759 | Nulls in revenue: 0
#    ALL_PURCHASES_ORIGINAL_PRICE  ALL_PURCHASES_GROSS_DISCOUNT      revenue
# 0                   4552.984240                    846.593069  3706.391171
# 1                   3177.998032                    613.806522  2564.191509
# 2                   5468.998818                   1504.997966  3964.000852
# 3                   3335.970202                    754.410747  2581.559455
# 4                   3991.987441                    934.011083  3057.976358

# %%
# Add core time controls to reduce bias in ROI modeling.
df["DATE_DAY"] = pd.to_datetime(df["DATE_DAY"])

df["day_of_week"] = df["DATE_DAY"].dt.dayofweek  # Monday=0, Sunday=6
df["month"] = df["DATE_DAY"].dt.month

# Monotonic time index across the dataset.
df = df.sort_values("DATE_DAY").reset_index(drop=True)
df["trend"] = np.arange(len(df), dtype=int)

print("Created control features: day_of_week, month, trend")
df[["DATE_DAY", "day_of_week", "month", "trend"]].head()
# Out:
# Created control features: day_of_week, month, trend
#     DATE_DAY  day_of_week  month  trend
# 0 2019-07-21            6      7      0
# 1 2019-07-22            0      7      1
# 2 2019-07-23            1      7      2
# 3 2019-07-24            2      7      3
# 4 2019-07-25            3      7      4

# %%
# Final clean modeling table.
required_model_cols = [
    "DATE_DAY",
    "ORGANISATION_ID",
    "GOOGLE_TOTAL_SPEND",
    "META_TOTAL_SPEND",
    "TIKTOK_SPEND",
    "revenue",
    "day_of_week",
    "month",
    "trend",
]

missing_model_cols = [c for c in required_model_cols if c not in df.columns]
if missing_model_cols:
    raise KeyError(f"Missing required modeling columns: {missing_model_cols}")

model_df = df[required_model_cols].rename(
    columns={
        "DATE_DAY": "date",
        "ORGANISATION_ID": "brand_id",
        "GOOGLE_TOTAL_SPEND": "spend_google",
        "META_TOTAL_SPEND": "spend_meta",
        "TIKTOK_SPEND": "spend_tiktok",
        "trend": "time_index",
    }
).copy()

# Treat missing TikTok spend as zero spend.
model_df["spend_tiktok"] = model_df["spend_tiktok"].fillna(0.0)

# Keep a consistent order for modeling pipelines.
model_df = model_df[[
    "date",
    "brand_id",
    "spend_google",
    "spend_meta",
    "spend_tiktok",
    "revenue",
    "day_of_week",
    "month",
    "time_index",
]].sort_values(["date", "brand_id"]).reset_index(drop=True)

print("Final modeling table created.")
print(f"Shape: {model_df.shape[0]:,} rows x {model_df.shape[1]} columns")
model_df.head()
# Out:
# Final modeling table created.
# Shape: 132,759 rows x 9 columns
#         date                          brand_id  spend_google  spend_meta  \
# 0 2019-07-21  0d1fc3f1715b0c65776780e7ad8ac7df    108.900605         0.0
# 1 2019-07-22  0d1fc3f1715b0c65776780e7ad8ac7df    109.074052         0.0
# 2 2019-07-23  0d1fc3f1715b0c65776780e7ad8ac7df    106.960857         0.0
# 3 2019-07-24  0d1fc3f1715b0c65776780e7ad8ac7df    119.483514         0.0
# 4 2019-07-25  0d1fc3f1715b0c65776780e7ad8ac7df     92.153581         0.0
#
#    spend_tiktok      revenue  day_of_week  month  time_index
# 0           0.0  3840.280350            6      7           0
# 1           0.0  3682.544986            0      7           1
# 2           0.0  2951.282461            1      7           2
# 3           0.0  3728.437604            2      7           3
# 4           0.0  2777.700946            3      7           4

# %%
# Marginal ROI from a log-log model.
channels = ["spend_google", "spend_meta", "spend_tiktok"]

# Log-log requires strictly positive values.
fit_df = model_df[["revenue"] + channels].copy()
valid_fit = (fit_df["revenue"] > 0)
for c in channels:
    valid_fit &= (fit_df[c] > 0)

fit_df = fit_df.loc[valid_fit].copy()
dropped = len(model_df) - len(fit_df)
print(f"Rows used for log-log fit: {len(fit_df):,} | Dropped (non-positive revenue/spend): {dropped:,}")

if len(fit_df) < 30:
    raise ValueError("Too few rows for stable log-log fit after filtering positives.")

# OLS via numpy (no extra dependency).
X = np.column_stack([np.ones(len(fit_df))] + [np.log(fit_df[c].values) for c in channels])
y_log = np.log(fit_df["revenue"].values)
coef, _, _, _ = np.linalg.lstsq(X, y_log, rcond=None)

elasticity = pd.Series(coef[1:], index=channels, name="elasticity")
print("Elasticities (beta):")
print(elasticity)

# Compute marginal ROI per row: mROI = beta * (revenue / spend).
for c in channels:
    model_df[f"mroi_{c.replace('spend_', '')}"] = np.where(
        model_df[c] > 0,
        elasticity[c] * (model_df["revenue"] / model_df[c]),
        np.nan,
    )

mroi_summary = pd.DataFrame({
    "channel": channels,
    "elasticity": [elasticity[c] for c in channels],
    "avg_mROI": [model_df[f"mroi_{c.replace('spend_', '')}"].mean(skipna=True) for c in channels],
    "median_mROI": [model_df[f"mroi_{c.replace('spend_', '')}"].median(skipna=True) for c in channels],
})

mroi_summary
# Out:
# Rows used for log-log fit: 3,212 | Dropped (non-positive revenue/spend): 129,547
# Elasticities (beta):
# spend_google    0.357606
# spend_meta      0.429034
# spend_tiktok    0.064411
# Name: elasticity, dtype: float64
#         channel  elasticity    avg_mROI  median_mROI
# 0  spend_google    0.357606  144.966861     6.704613
# 1    spend_meta    0.429034  384.262894     5.822012
# 2  spend_tiktok    0.064411   39.120196     3.253639

# %%
# Quick fix: log1p model keeps zero-spend and zero-revenue rows.
channels = ["spend_google", "spend_meta", "spend_tiktok"]

fit_df_log1p = model_df[["revenue"] + channels].copy()

# Only impossible values are negatives; zeros are allowed with log1p.
valid_log1p = (fit_df_log1p["revenue"] >= 0)
for c in channels:
    valid_log1p &= (fit_df_log1p[c] >= 0)

fit_df_log1p = fit_df_log1p.loc[valid_log1p].copy()
dropped_log1p = len(model_df) - len(fit_df_log1p)
print(f"Rows used for log1p fit: {len(fit_df_log1p):,} | Dropped (negative values): {dropped_log1p:,}")

# log(revenue + 1) ~ log(spend + 1)
X_log1p = np.column_stack([
    np.ones(len(fit_df_log1p))
    ] + [np.log1p(fit_df_log1p[c].values) for c in channels]
 )
y_log1p = np.log1p(fit_df_log1p["revenue"].values)
coef_log1p, _, _, _ = np.linalg.lstsq(X_log1p, y_log1p, rcond=None)

elasticity_log1p = pd.Series(coef_log1p[1:], index=channels, name="elasticity_log1p")
print("Log1p elasticities (beta):")
print(elasticity_log1p)

# mROI approximation using beta * (revenue / spend), undefined where spend==0.
for c in channels:
    model_df[f"mroi_log1p_{c.replace('spend_', '')}"] = np.where(
        model_df[c] > 0,
        elasticity_log1p[c] * (model_df["revenue"] / model_df[c]),
        np.nan,
    )

mroi_log1p_summary = pd.DataFrame({
    "channel": channels,
    "elasticity_log1p": [elasticity_log1p[c] for c in channels],
    "avg_mROI_log1p": [model_df[f"mroi_log1p_{c.replace('spend_', '')}"].mean(skipna=True) for c in channels],
    "median_mROI_log1p": [model_df[f"mroi_log1p_{c.replace('spend_', '')}"].median(skipna=True) for c in channels],
})

mroi_log1p_summary
# Out:
# Rows used for log1p fit: 132,759 | Dropped (negative values): 0
# Log1p elasticities (beta):
# spend_google    0.419683
# spend_meta      0.041248
# spend_tiktok   -0.072052
# Name: elasticity_log1p, dtype: float64
#         channel  elasticity_log1p  avg_mROI_log1p  median_mROI_log1p
# 0  spend_google          0.419683      170.131822           7.868474
# 1    spend_meta          0.041248       36.943461           0.559735
# 2  spend_tiktok         -0.072052      -43.760654          -3.639587

# %%
# Quick fixes: time controls, lag features, weekly aggregation, and correlation sanity check.
work_df = model_df.copy()
work_df["date"] = pd.to_datetime(work_df["date"])

work_df = work_df.sort_values(["brand_id", "date"]).reset_index(drop=True)

# 1) Time controls
work_df["time_index"] = (work_df["date"] - work_df["date"].min()).dt.days
work_df["day_of_week"] = work_df["date"].dt.dayofweek
work_df["month"] = work_df["date"].dt.month

# C(day_of_week) and C(month) via one-hot encoding (drop_first avoids full collinearity).
dow_dummies = pd.get_dummies(work_df["day_of_week"], prefix="dow", drop_first=True, dtype=int)
month_dummies = pd.get_dummies(work_df["month"], prefix="month", drop_first=True, dtype=int)

# 2) Adstock-lite lags (within brand).
work_df["meta_lag1"] = work_df.groupby("brand_id")["spend_meta"].shift(1).fillna(0.0)
work_df["google_lag1"] = work_df.groupby("brand_id")["spend_google"].shift(1).fillna(0.0)

# Feature table for modeling.
model_features = pd.concat([
    work_df[[
        "date",
        "brand_id",
        "revenue",
        "spend_google",
        "spend_meta",
        "spend_tiktok",
        "google_lag1",
        "meta_lag1",
        "time_index",
        "day_of_week",
        "month",
    ]],
    dow_dummies,
    month_dummies,
], axis=1)

# 3) Weekly aggregation (less noisy than daily).
work_df["week"] = work_df["date"].dt.to_period("W").dt.start_time
weekly_df = (
    work_df.groupby(["week", "brand_id"], as_index=False)[
        ["revenue", "spend_google", "spend_meta", "spend_tiktok", "google_lag1", "meta_lag1"]
    ]
    .sum()
    .sort_values(["brand_id", "week"])
    .reset_index(drop=True)
)
weekly_df["time_index"] = ((weekly_df["week"] - weekly_df["week"].min()).dt.days // 7).astype(int)
weekly_df["day_of_week"] = weekly_df["week"].dt.dayofweek
weekly_df["month"] = weekly_df["week"].dt.month

# 4) Correlation sanity checks.
corr_daily = work_df[["revenue", "spend_meta", "spend_google", "spend_tiktok"]].corr(numeric_only=True)
corr_weekly = weekly_df[["revenue", "spend_meta", "spend_google", "spend_tiktok"]].corr(numeric_only=True)

print("Built model_features with time controls + lag features.")
print(f"Daily rows: {len(work_df):,} | Weekly rows: {len(weekly_df):,}")
print("Suggested formula:")
print("np.log1p(revenue) ~ np.log1p(spend_google) + np.log1p(spend_meta) + np.log1p(spend_tiktok) + np.log1p(google_lag1) + np.log1p(meta_lag1) + time_index + C(day_of_week) + C(month)")

print("\nDaily correlation matrix:")
display(corr_daily)
print("\nWeekly correlation matrix:")
display(corr_weekly)

weekly_df.head()
# Out:
# Built model_features with time controls + lag features.
# Daily rows: 132,759 | Weekly rows: 12,078
# Suggested formula:
# np.log1p(revenue) ~ np.log1p(spend_google) + np.log1p(spend_meta) + np.log1p(spend_tiktok) + np.log1p(google_lag1) + np.log1p(meta_lag1) + time_index + C(day_of_week) + C(month)
#
# Daily correlation matrix:
#                revenue  spend_meta  spend_google  spend_tiktok
# revenue       1.000000    0.906030      0.691419     -0.004604
# spend_meta    0.906030    1.000000      0.828112     -0.001801
# spend_google  0.691419    0.828112      1.000000      0.011854
# spend_tiktok -0.004604   -0.001801      0.011854      1.000000
# Weekly correlation matrix:
#                revenue  spend_meta  spend_google  spend_tiktok
# revenue       1.000000    0.948294      0.821102     -0.005356
# spend_meta    0.948294    1.000000      0.898543     -0.000490
# spend_google  0.821102    0.898543      1.000000      0.023632
# spend_tiktok -0.005356   -0.000490      0.023632      1.000000
#         week                          brand_id       revenue  spend_google  \
# 0 2022-07-25  04769dac8b828ec7a85676d9e2bffe6f  10234.583533    910.047359
# 1 2022-08-01  04769dac8b828ec7a85676d9e2bffe6f  24369.796334   2721.559535
# 2 2022-08-08  04769dac8b828ec7a85676d9e2bffe6f  25600.447481   2740.750000
# 3 2022-08-15  04769dac8b828ec7a85676d9e2bffe6f  27406.648086   3057.470000
# 4 2022-08-22  04769dac8b828ec7a85676d9e2bffe6f  28202.390801   2817.470000
#
#    spend_meta  spend_tiktok  google_lag1  meta_lag1  time_index  day_of_week  \
# 0      757.10           0.0   482.610930     482.59         158            0
# 1     1299.81           0.0  2781.435965    1425.26         159            0
# 2     1015.49           0.0  2707.420000    1015.82         160            0
# 3     1010.78           0.0  2946.170000    1010.59         161            0
# 4     1037.69           0.0  2860.540000    1029.87         162            0
#
#    month
# 0      7
# 1      8
# 2      8
# 3      8
# 4      8

# %%
# Collinearity fix: combine Google + Meta into one performance channel.
combo_df = model_df.copy()

combo_df["performance_spend"] = combo_df["spend_google"] + combo_df["spend_meta"]

# Keep zeros with log1p; drop only impossible negatives.
fit_combo = combo_df[["revenue", "performance_spend", "spend_tiktok"]].copy()
valid_combo = (
    (fit_combo["revenue"] >= 0)
    & (fit_combo["performance_spend"] >= 0)
    & (fit_combo["spend_tiktok"] >= 0)
)
fit_combo = fit_combo.loc[valid_combo].copy()

print(f"Rows used (combined-channel model): {len(fit_combo):,} / {len(combo_df):,}")

# log1p(revenue) ~ log1p(performance_spend) + log1p(tiktok)
X_combo = np.column_stack([
    np.ones(len(fit_combo)),
    np.log1p(fit_combo["performance_spend"].values),
    np.log1p(fit_combo["spend_tiktok"].values),
])
y_combo = np.log1p(fit_combo["revenue"].values)
coef_combo, _, _, _ = np.linalg.lstsq(X_combo, y_combo, rcond=None)

elasticity_combo = pd.Series(
    {
        "performance_spend": coef_combo[1],
        "spend_tiktok": coef_combo[2],
    },
    name="elasticity_log1p",
)
print("Combined-channel elasticities (log1p model):")
print(elasticity_combo)

# mROI approximation: beta * (revenue / spend), undefined where spend == 0.
combo_df["mroi_performance"] = np.where(
    combo_df["performance_spend"] > 0,
    elasticity_combo["performance_spend"] * (combo_df["revenue"] / combo_df["performance_spend"]),
    np.nan,
)
combo_df["mroi_tiktok_combo"] = np.where(
    combo_df["spend_tiktok"] > 0,
    elasticity_combo["spend_tiktok"] * (combo_df["revenue"] / combo_df["spend_tiktok"]),
    np.nan,
)

combo_mroi_summary = pd.DataFrame({
    "channel": ["performance_spend", "spend_tiktok"],
    "elasticity_log1p": [
        elasticity_combo["performance_spend"],
        elasticity_combo["spend_tiktok"],
    ],
    "avg_mROI": [
        combo_df["mroi_performance"].mean(skipna=True),
        combo_df["mroi_tiktok_combo"].mean(skipna=True),
    ],
    "median_mROI": [
        combo_df["mroi_performance"].median(skipna=True),
        combo_df["mroi_tiktok_combo"].median(skipna=True),
    ],
})

combo_mroi_summary
# Out:
# Rows used (combined-channel model): 132,759 / 132,759
# Combined-channel elasticities (log1p model):
# performance_spend    0.471787
# spend_tiktok        -0.081540
# Name: elasticity_log1p, dtype: float64
#              channel  elasticity_log1p    avg_mROI  median_mROI
# 0  performance_spend          0.471787  118.635303     4.828198
# 1       spend_tiktok         -0.081540  -49.523311    -4.118869

# %%
# Sequential modeling on weekly data (recommended for decisions).

# Build weekly data if the earlier quick-fix cell was not run.
if "weekly_df" not in globals():
    temp = model_df.copy()
    temp["date"] = pd.to_datetime(temp["date"])
    temp["week"] = temp["date"].dt.to_period("W").dt.start_time
    weekly_df = (
        temp.groupby(["week", "brand_id"], as_index=False)[
            ["revenue", "spend_google", "spend_meta", "spend_tiktok"]
        ]
        .sum()
        .sort_values(["brand_id", "week"])
        .reset_index(drop=True)
    )

# Step 1: Model total performance at weekly level.
w = weekly_df.copy()
for c in ["revenue", "spend_google", "spend_meta", "spend_tiktok"]:
    w[c] = pd.to_numeric(w[c], errors="coerce")

valid = (w["revenue"] >= 0) & (w["spend_google"] >= 0) & (w["spend_meta"] >= 0) & (w["spend_tiktok"] >= 0)
w_fit = w.loc[valid].copy()
w_fit["performance_spend"] = w_fit["spend_google"] + w_fit["spend_meta"]

X_seq = np.column_stack([
    np.ones(len(w_fit)),
    np.log1p(w_fit["performance_spend"].values),
    np.log1p(w_fit["spend_tiktok"].values),
])
y_seq = np.log1p(w_fit["revenue"].values)
coef_seq, _, _, _ = np.linalg.lstsq(X_seq, y_seq, rcond=None)

weekly_elasticity = pd.Series(
    {
        "performance_spend": coef_seq[1],
        "spend_tiktok": coef_seq[2],
    },
    name="weekly_elasticity_log1p",
)

print("Weekly sequential model fitted (recommended decision view).")
print("Step 1 model: log1p(revenue) ~ log1p(performance_spend) + log1p(spend_tiktok)")
print(weekly_elasticity)

# Step 2: Meta vs Google split using business efficiency metrics when available.
# Expected optional columns in model_df:
#  - cac_google, cac_meta
#  - conv_rate_google, conv_rate_meta
#  - click_eff_google, click_eff_meta

split_inputs = [
    "cac_google", "cac_meta",
    "conv_rate_google", "conv_rate_meta",
    "click_eff_google", "click_eff_meta",
]

available_split_cols = [c for c in split_inputs if c in model_df.columns]
if len(available_split_cols) == len(split_inputs):
    split_df = model_df[split_inputs].copy()
    split_df = split_df.apply(pd.to_numeric, errors="coerce")
    split_df = split_df.dropna()

    if len(split_df) > 0:
        # Higher score means expected better marginal efficiency.
        google_score = (split_df["conv_rate_google"] * split_df["click_eff_google"]) / split_df["cac_google"].replace(0, np.nan)
        meta_score = (split_df["conv_rate_meta"] * split_df["click_eff_meta"]) / split_df["cac_meta"].replace(0, np.nan)

        score_df = pd.DataFrame({"google_score": google_score, "meta_score": meta_score}).replace([np.inf, -np.inf], np.nan).dropna()
        google_share = (score_df["google_score"] / (score_df["google_score"] + score_df["meta_score"])).mean()
        meta_share = 1 - google_share

        split_summary = pd.DataFrame({
            "channel": ["google", "meta"],
            "avg_efficiency_share": [google_share, meta_share],
        })
        print("\nStep 2 split (from CAC + conversion + click efficiency):")
        display(split_summary)
    else:
        print("\nStep 2 split skipped: split columns exist but have no complete rows.")
else:
    missing_split_cols = [c for c in split_inputs if c not in model_df.columns]
    print("\nStep 2 split skipped: missing business metrics columns.")
    print(f"Missing: {missing_split_cols}")

print("\nWeekly is preferred for decisions: smoother, less noisy, and usually more stable coefficients.")
# Out:
# Weekly sequential model fitted (recommended decision view).
# Step 1 model: log1p(revenue) ~ log1p(performance_spend) + log1p(spend_tiktok)
# performance_spend    0.670607
# spend_tiktok        -0.081987
# Name: weekly_elasticity_log1p, dtype: float64
#
# Step 2 split skipped: missing business metrics columns.
# Missing: ['cac_google', 'cac_meta', 'conv_rate_google', 'conv_rate_meta', 'click_eff_google', 'click_eff_meta']
#
# Weekly is preferred for decisions: smoother, less noisy, and usually more stable coefficients.

# %%
# 1) Spend -> Revenue response curves by channel (with simple saturation detection).
import matplotlib.pyplot as plt

# Prefer weekly data for smoother signal when available.
curve_df = weekly_df.copy() if "weekly_df" in globals() else model_df.copy()

channels = ["spend_google", "spend_meta", "spend_tiktok"]
for c in channels + ["revenue"]:
    curve_df[c] = pd.to_numeric(curve_df[c], errors="coerce")

curve_df = curve_df.dropna(subset=["revenue"] + channels).copy()
curve_df = curve_df[curve_df["revenue"] >= 0].copy()

fig, axes = plt.subplots(1, 3, figsize=(18, 5), sharey=True)
saturation_rows = []

for ax, c in zip(axes, channels):
    temp = curve_df[[c, "revenue"]].copy()
    temp = temp[temp[c] > 0].sort_values(c)

    # Raw points
    ax.scatter(temp[c], temp["revenue"], alpha=0.12, s=12, color="#3A6EA5")

    # Quantile-binned mean response curve
    n_bins = min(20, temp[c].nunique())
    if n_bins >= 5:
        temp["bin"] = pd.qcut(temp[c], q=n_bins, duplicates="drop")
        curve = temp.groupby("bin", observed=True).agg(
            spend=(c, "mean"),
            revenue=("revenue", "mean")
        ).dropna().sort_values("spend")

        ax.plot(curve["spend"], curve["revenue"], color="#D1495B", linewidth=2.5)

        # Simple flattening rule: first point where slope < 20% of initial positive slope.
        slope = np.diff(curve["revenue"].values) / np.diff(curve["spend"].values)
        positive_slope = slope[slope > 0]
        sat_spend = np.nan
        if len(positive_slope) > 0:
            baseline = positive_slope[0]
            threshold = 0.2 * baseline
            idx = np.where(slope < threshold)[0]
            if len(idx) > 0:
                sat_spend = curve["spend"].iloc[idx[0] + 1]

        saturation_rows.append({
            "channel": c,
            "saturation_spend_estimate": sat_spend,
            "curve_points": len(curve),
        })

        if pd.notna(sat_spend):
            ax.axvline(sat_spend, color="#2A9D8F", linestyle="--", linewidth=1.8)
            ax.text(
                sat_spend,
                ax.get_ylim()[1] * 0.92,
                f"Sat ~ ${sat_spend:,.0f}",
                color="#2A9D8F",
                rotation=90,
                va="top",
                ha="right",
            )
    else:
        saturation_rows.append({
            "channel": c,
            "saturation_spend_estimate": np.nan,
            "curve_points": 0,
        })

    ax.set_title(c.replace("spend_", "").capitalize())
    ax.set_xlabel("Spend")

axes[0].set_ylabel("Revenue")
plt.suptitle("Spend -> Revenue Response Curves")
plt.tight_layout()
plt.show()

saturation_summary = pd.DataFrame(saturation_rows)
saturation_summary["note"] = np.where(
    saturation_summary["saturation_spend_estimate"].notna(),
    saturation_summary["channel"].str.replace("spend_", "", regex=False).str.capitalize()
    + " flattens after ~$"
    + saturation_summary["saturation_spend_estimate"].round(0).map(lambda x: f"{x:,.0f}"),
    "No clear saturation detected with current data",
)

saturation_summary
# Out:
#         channel  saturation_spend_estimate  curve_points  \
# 0  spend_google                 538.539052            20
# 1    spend_meta                 279.591371            20
# 2  spend_tiktok                 305.040146            20
#
#                           note
# 0  Google flattens after ~$539
# 1    Meta flattens after ~$280
# 2  Tiktok flattens after ~$305

# %%
# Marginal ROI curves: x = spend, y = marginal ROI
channels = [
    ("spend_google", "mroi_log1p_google", "Google"),
    ("spend_meta", "mroi_log1p_meta", "Meta"),
    ("spend_tiktok", "mroi_log1p_tiktok", "TikTok"),
]

fig, axes = plt.subplots(1, 3, figsize=(18, 5), sharey=True)
summary_rows = []

for ax, (spend_col, mroi_col, label) in zip(axes, channels):
    if mroi_col not in model_df.columns:
        ax.set_title(f"{label} (missing {mroi_col})")
        ax.axis("off")
        continue

    d = model_df[[spend_col, mroi_col]].copy()
    d = d.replace([np.inf, -np.inf], np.nan).dropna()
    d = d[d[spend_col] > 0].sort_values(spend_col)

    if d.empty:
        ax.set_title(f"{label} (no valid data)")
        ax.axis("off")
        continue

    # Raw cloud
    ax.scatter(d[spend_col], d[mroi_col], s=10, alpha=0.08, color="#4C78A8")

    # Smoothed curve via spend quantiles
    n_bins = min(20, d[spend_col].nunique())
    d["bin"] = pd.qcut(d[spend_col], q=n_bins, duplicates="drop")
    curve = d.groupby("bin", observed=True).agg(
        spend=(spend_col, "median"),
        mroi=(mroi_col, "median")
    ).dropna().sort_values("spend")

    ax.plot(curve["spend"], curve["mroi"], color="#E45756", linewidth=2.5)
    ax.axhline(1.0, color="#2A9D8F", linestyle="--", linewidth=1.5)  # break-even mROI

    # "Optimal" spend zone: where smoothed mROI >= 1
    good = curve[curve["mroi"] >= 1.0]
    opt_low = good["spend"].min() if not good.empty else np.nan
    opt_high = good["spend"].max() if not good.empty else np.nan

    if pd.notna(opt_low) and pd.notna(opt_high):
        ax.axvspan(opt_low, opt_high, color="#2A9D8F", alpha=0.12)
        ax.set_title(f"{label}\nOptimal zone ~ [{opt_low:,.0f}, {opt_high:,.0f}]")
    else:
        ax.set_title(f"{label}\nNo clear mROI>=1 zone")

    ax.set_xlabel("Spend")
    ax.set_ylabel("Marginal ROI")

    summary_rows.append({
        "channel": label,
        "median_spend": d[spend_col].median(),
        "median_mroi": d[mroi_col].median(),
        "optimal_spend_low": opt_low,
        "optimal_spend_high": opt_high,
        "under_alloc_share": (
            ((d[spend_col] < opt_low) & (d[mroi_col] > 1)).mean()
            if pd.notna(opt_low) else np.nan
        ),
        "over_alloc_share": (
            ((d[spend_col] > opt_high) & (d[mroi_col] < 1)).mean()
            if pd.notna(opt_high) else np.nan
        ),
    })

plt.suptitle("Marginal ROI Curves by Channel")
plt.tight_layout()
plt.show()

mroi_curve_summary = pd.DataFrame(summary_rows)
mroi_curve_summary
# Out:
#   channel  median_spend  median_mroi  optimal_spend_low  optimal_spend_high  \
# 0  Google    416.029984     7.868474          13.910000         7055.965140
# 1    Meta    348.369902     0.559735           6.751362          108.207518
# 2  TikTok    140.011246    -3.639587                NaN                 NaN
#
#    under_alloc_share  over_alloc_share
# 0           0.024963          0.000425
# 1           0.024926          0.549978
# 2                NaN               NaN
